# %% [markdown]
# # MobileNet - KHOTAA Diabetic Foot Ulcer Classification

# %% [markdown]
# ## 1. Imports & Configuration

# %%
import sys
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from torchvision.models import mobilenet_v2, MobileNet_V2_Weights
import numpy as np
from sklearn.model_selection import StratifiedKFold
import importlib

sys.path.append('../')
sys.path.append('./')

from dataset_loader import SplitFolderDatasetLoader
from dataset_preprocessing import DFUPreprocessing
from utils import checkpoint_manager, training_engine
importlib.reload(checkpoint_manager)  # Reload to remove N/A print
importlib.reload(training_engine)  # Reload to get latest fixes
from utils.checkpoint_manager import CheckpointManager
from utils.training_engine import TrainingEngine, create_optimizer
from utils.metrics_evaluator import (
    calculate_metrics, print_metrics, plot_confusion_matrix,
    plot_roc_curve, plot_training_history
)

print("✓ Imports complete (modules reloaded)")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
# Out:
# ✓ Imports complete (modules reloaded)
# PyTorch version: 2.8.0
# CUDA available: False

# %% [markdown]
# ## 2. Load Dataset

# %%
# Load dataset
loader = SplitFolderDatasetLoader(root_dir='../../dfu-dataset-annotated-into-4-classes')
classes = loader.get_classes()
num_classes = loader.get_num_classes()

print(f"Classes: {classes}")
print(f"Number of classes: {num_classes}")

# Initialize preprocessing
preprocessor = DFUPreprocessing()
train_transform = preprocessor.get_train_transforms()
val_test_transform = preprocessor.get_valid_test_transforms()

# Dataset class
class DFUDataset(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.transform = transform
    
    def __len__(self):
        return len(self.image_paths)
    
    def __getitem__(self, idx):
        from PIL import Image
        image = Image.open(self.image_paths[idx]).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, self.labels[idx]

# Prepare data for cross-validation
X_train, y_train = loader.load_split_paths('train', shuffle=True)
X_val, y_val = loader.load_split_paths('valid')
X_all = np.concatenate([X_train, X_val])  # Concatenate numpy arrays
y_all = np.concatenate([y_train, y_val])

# Test set (untouched until final evaluation)
X_test, y_test = loader.load_split_paths('test')
test_dataset = DFUDataset(X_test, y_test, transform=val_test_transform)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=0)  # num_workers=0 to avoid multiprocessing issues

# Initialize 5-fold stratified cross-validation
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

print(f"\nTotal training samples (train+valid): {len(X_all)}")
print(f"Test samples: {len(X_test)}")
print("✓ Dataset loaded and ready for 5-fold cross-validation")
# Out:
# [DatasetLoader] Root: /Users/manaralharbi/Desktop/KHOTAA/dfu-dataset-annotated-into-4-classes
# [DatasetLoader] Splits: ['train', 'valid', 'test']
# [DatasetLoader] Classes (4): ['Grade 1', 'Grade 2', 'Grade 3', 'Grade 4']
# Classes: ['Grade 1', 'Grade 2', 'Grade 3', 'Grade 4']
# Number of classes: 4
# [DFUPreprocessing] Initialized
# [DFUPreprocessing] Image size: 224x224
# [DFUPreprocessing] Train: with augmentation
# [DFUPreprocessing] Valid/Test: no augmentation
# [DatasetLoader] Split 'train': 9639 images
# [DatasetLoader] Split 'valid': 282 images
# [DatasetLoader] Split 'test': 141 images
#
# Total training samples (train+valid): 9921
# Test samples: 141
# ✓ Dataset loaded and ready for 5-fold cross-validation

# %% [markdown]
# ## 3. Model Definition

# %%
# Setup device and loss function
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
criterion = nn.CrossEntropyLoss()

print(f"Device: {device}")

# Create MobileNetV2 model
def create_mobilenet_model(num_classes=4, pretrained=True):
    """
    Create MobileNetV2 model for DFU classification.
    
    Args:
        num_classes: Number of output classes (4 for DFU grades)
        pretrained: Use ImageNet pretrained weights
    
    Returns:
        MobileNetV2 model configured for DFU classification
    """
    if pretrained:
        model = models.mobilenet_v2(weights=MobileNet_V2_Weights.IMAGENET1K_V1)
    else:
        model = models.mobilenet_v2(weights=None)
    
    # Modify final classifier layer
    # MobileNet classifier is: Linear(1280 -> 1000)
    # Replace with: Linear(1280 -> num_classes)
    model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
    
    return model

# Test model creation
test_model = create_mobilenet_model(num_classes=num_classes)
print(f"\n✓ MobileNetV2 model created")
print(f"Input size: 224x224")
print(f"Output classes: {num_classes}")
print(f"Final classifier: {test_model.classifier[1]}")
# Out:
# Device: cpu
#
# ✓ MobileNetV2 model created
# Input size: 224x224
# Output classes: 4
# Final classifier: Linear(in_features=1280, out_features=4, bias=True)

# %% [markdown]
# ## 4. Training

# %%
# 5-Fold Cross-Validation Training
fold_results = []

for fold, (train_idx, val_idx) in enumerate(kfold.split(X_all, y_all), 1):
    print(f"\n{'='*60}\nFOLD {fold}/5\n{'='*60}")
    
    # Prepare fold data (X_all is numpy array of paths)
    X_train_fold = X_all[train_idx]
    y_train_fold = y_all[train_idx]
    X_val_fold = X_all[val_idx]
    y_val_fold = y_all[val_idx]
    
    train_dataset = DFUDataset(X_train_fold, y_train_fold, transform=train_transform)
    val_dataset = DFUDataset(X_val_fold, y_val_fold, transform=val_test_transform)
    
    # num_workers=0 to avoid multiprocessing issues with notebook-defined classes
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=0)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=0)
    
    # Create model
    model = create_mobilenet_model(num_classes=num_classes, pretrained=True)
    model = model.to(device)
    
    # Setup optimizer using helper function (SGD with momentum=0.8)
    optimizer = create_optimizer(model, lr=0.001)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
    checkpoint_manager = CheckpointManager(base_dir='checkpoints', experiment_name=f'mobilenet_fold{fold}')
    engine = TrainingEngine(model=model, device=device)
    
    # Train
    history = engine.train(
        train_loader=train_loader,
        val_loader=val_loader,
        criterion=criterion,
        optimizer=optimizer,
        num_epochs=30,
        scheduler=scheduler,
        checkpoint_manager=checkpoint_manager,
        early_stopping_patience=7,
        use_early_stopping=True,
        verbose=True
    )
    
    # Store results
    best_val_acc = max(history['val_acc'])
    fold_results.append({
        'fold': fold,
        'best_val_acc': best_val_acc,
        'final_val_acc': history['val_acc'][-1],
        'stopped_epoch': history['stopped_epoch'],
        'history': history
    })
    print(f"Fold {fold} - Best Acc: {best_val_acc*100:.2f}% (stopped at epoch {history['stopped_epoch']})")

# Cross-validation summary
avg_acc = np.mean([r['best_val_acc'] for r in fold_results])
std_acc = np.std([r['best_val_acc'] for r in fold_results])
avg_epochs = np.mean([r['stopped_epoch'] for r in fold_results])

print(f"\n{'='*60}")
print(f"5-FOLD CROSS-VALIDATION RESULTS")
print(f"{'='*60}")
print(f"Mean Accuracy: {avg_acc*100:.2f}% ± {std_acc*100:.2f}%")
print(f"Average Epochs: {avg_epochs:.1f}")
print(f"\nIndividual Fold Results:")
for r in fold_results:
    print(f"  Fold {r['fold']}: {r['best_val_acc']*100:.2f}% (epoch {r['stopped_epoch']})")
print(f"{'='*60}")
# Out:
# ============================================================
# FOLD 1/5
# ============================================================
# Created SGD optimizer: lr=0.001, momentum=0.8, weight_decay=0.0001
# Training on: cpu
#
# ============================================================
# Epoch 1/30
# ============================================================
# Training: 100%|██████████| 248/248 [20:37<00:00,  4.99s/it, loss=0.8196, acc=55.00%]
# Training: 100%|██████████| 248/248 [20:37<00:00,  4.99s/it, loss=0.8196, acc=55.00%]
# Evaluating: 100%|██████████| 63/63 [01:12<00:00,  1.14s/it, loss=0.0786, acc=67.86%]
# Learning Rate: 0.001000
#
# Epoch 1 Results:
#    Train Loss: 1.0319 | Train Acc: 55.00%
#    Val Loss:   0.8087 | Val Acc:   67.86%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_1.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold1/fold_1/best_accuracy.pt
#  New best model! Val Acc: 67.86%
#
# ============================================================
# Epoch 2/30
# ============================================================
# Training: 100%|██████████| 248/248 [22:03<00:00,  5.34s/it, loss=0.6870, acc=67.96%]
# Training: 100%|██████████| 248/248 [22:03<00:00,  5.34s/it, loss=0.6870, acc=67.96%]
# Evaluating: 100%|██████████| 63/63 [01:03<00:00,  1.01s/it, loss=0.0377, acc=72.59%]
# Learning Rate: 0.001000
#
# Epoch 2 Results:
#    Train Loss: 0.7918 | Train Acc: 67.96%
#    Val Loss:   0.6831 | Val Acc:   72.59%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_2.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold1/fold_1/best_accuracy.pt
#  New best model! Val Acc: 72.59%
#
# ============================================================
# Epoch 3/30
# ============================================================
# Training: 100%|██████████| 248/248 [20:50<00:00,  5.04s/it, loss=0.5870, acc=73.08%]
# Training: 100%|██████████| 248/248 [20:50<00:00,  5.04s/it, loss=0.5870, acc=73.08%]
# Evaluating: 100%|██████████| 63/63 [01:01<00:00,  1.03it/s, loss=0.0181, acc=77.88%]
# Learning Rate: 0.001000
#
# Epoch 3 Results:
#    Train Loss: 0.6794 | Train Acc: 73.08%
#    Val Loss:   0.5857 | Val Acc:   77.88%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_3.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold1/fold_1/best_accuracy.pt
#  New best model! Val Acc: 77.88%
#
# ============================================================
# Epoch 4/30
# ============================================================
# Training: 100%|██████████| 248/248 [21:32<00:00,  5.21s/it, loss=0.4903, acc=77.15%]
# Training: 100%|██████████| 248/248 [21:32<00:00,  5.21s/it, loss=0.4903, acc=77.15%]
# Evaluating: 100%|██████████| 63/63 [01:04<00:00,  1.02s/it, loss=0.0049, acc=82.72%]
# Learning Rate: 0.001000
#
# Epoch 4 Results:
#    Train Loss: 0.5774 | Train Acc: 77.15%
#    Val Loss:   0.4762 | Val Acc:   82.72%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_4.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold1/fold_1/best_accuracy.pt
#  New best model! Val Acc: 82.72%
#
# ============================================================
# Epoch 5/30
# ============================================================
# Training: 100%|██████████| 248/248 [21:19<00:00,  5.16s/it, loss=0.1997, acc=82.70%]
# Training: 100%|██████████| 248/248 [21:19<00:00,  5.16s/it, loss=0.1997, acc=82.70%]
# Evaluating: 100%|██████████| 63/63 [00:48<00:00,  1.31it/s, loss=0.0129, acc=84.99%]
# Learning Rate: 0.001000
#
# Epoch 5 Results:
#    Train Loss: 0.4614 | Train Acc: 82.70%
#    Val Loss:   0.4194 | Val Acc:   84.99%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_5.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold1/fold_1/best_accuracy.pt
#  New best model! Val Acc: 84.99%
#
# ============================================================
# Epoch 6/30
# ============================================================
# Training: 100%|██████████| 248/248 [19:56<00:00,  4.83s/it, loss=0.1949, acc=85.55%]
# Training: 100%|██████████| 248/248 [19:56<00:00,  4.83s/it, loss=0.1949, acc=85.55%]
# Evaluating: 100%|██████████| 63/63 [00:54<00:00,  1.15it/s, loss=0.0026, acc=88.72%]
# Learning Rate: 0.001000
#
# Epoch 6 Results:
#    Train Loss: 0.3937 | Train Acc: 85.55%
#    Val Loss:   0.3285 | Val Acc:   88.72%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_6.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold1/fold_1/best_accuracy.pt
#  New best model! Val Acc: 88.72%
#
# ============================================================
# Epoch 7/30
# ============================================================
# Training: 100%|██████████| 248/248 [21:33<00:00,  5.22s/it, loss=0.2359, acc=88.52%]
# Training: 100%|██████████| 248/248 [21:33<00:00,  5.22s/it, loss=0.2359, acc=88.52%]
# Evaluating: 100%|██████████| 63/63 [01:00<00:00,  1.04it/s, loss=0.0005, acc=92.04%]
# Learning Rate: 0.001000
#
# Epoch 7 Results:
#    Train Loss: 0.3201 | Train Acc: 88.52%
#    Val Loss:   0.2271 | Val Acc:   92.04%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_7.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold1/fold_1/best_accuracy.pt
#  New best model! Val Acc: 92.04%
#
# ============================================================
# Epoch 8/30
# ============================================================
# Training: 100%|██████████| 248/248 [21:00<00:00,  5.08s/it, loss=0.1173, acc=90.76%]
# Training: 100%|██████████| 248/248 [21:00<00:00,  5.08s/it, loss=0.1173, acc=90.76%]
# Evaluating: 100%|██████████| 63/63 [00:47<00:00,  1.31it/s, loss=0.0001, acc=93.30%]
# Learning Rate: 0.001000
#
# Epoch 8 Results:
#    Train Loss: 0.2663 | Train Acc: 90.76%
#    Val Loss:   0.2141 | Val Acc:   93.30%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_8.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold1/fold_1/best_accuracy.pt
#  New best model! Val Acc: 93.30%
#
# ============================================================
# Epoch 9/30
# ============================================================
# Training: 100%|██████████| 248/248 [19:48<00:00,  4.79s/it, loss=0.4119, acc=91.67%]
# Training: 100%|██████████| 248/248 [19:48<00:00,  4.79s/it, loss=0.4119, acc=91.67%]
# Evaluating: 100%|██████████| 63/63 [00:55<00:00,  1.13it/s, loss=0.0001, acc=94.61%]
# Learning Rate: 0.001000
#
# Epoch 9 Results:
#    Train Loss: 0.2409 | Train Acc: 91.67%
#    Val Loss:   0.1696 | Val Acc:   94.61%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_9.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold1/fold_1/best_accuracy.pt
#  New best model! Val Acc: 94.61%
#
# ============================================================
# Epoch 10/30
# ============================================================
# Training: 100%|██████████| 248/248 [19:37<00:00,  4.75s/it, loss=0.2280, acc=93.31%]
# Training: 100%|██████████| 248/248 [19:37<00:00,  4.75s/it, loss=0.2280, acc=93.31%]
# Evaluating: 100%|██████████| 63/63 [00:56<00:00,  1.12it/s, loss=0.0019, acc=95.57%]
# Learning Rate: 0.000100
#
# Epoch 10 Results:
#    Train Loss: 0.1979 | Train Acc: 93.31%
#    Val Loss:   0.1355 | Val Acc:   95.57%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_10.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold1/fold_1/best_accuracy.pt
#  New best model! Val Acc: 95.57%
#
# ============================================================
# Epoch 11/30
# ============================================================
# Training: 100%|██████████| 248/248 [20:11<00:00,  4.88s/it, loss=0.0640, acc=95.30%]
# Training: 100%|██████████| 248/248 [20:11<00:00,  4.88s/it, loss=0.0640, acc=95.30%]
# Evaluating: 100%|██████████| 63/63 [00:59<00:00,  1.06it/s, loss=0.0007, acc=97.18%]
# Learning Rate: 0.000100
#
# Epoch 11 Results:
#    Train Loss: 0.1463 | Train Acc: 95.30%
#    Val Loss:   0.1038 | Val Acc:   97.18%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_11.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold1/fold_1/best_accuracy.pt
#  New best model! Val Acc: 97.18%
#
# ============================================================
# Epoch 12/30
# ============================================================
# Training: 100%|██████████| 248/248 [20:21<00:00,  4.93s/it, loss=0.2113, acc=95.78%]
# Training: 100%|██████████| 248/248 [20:21<00:00,  4.93s/it, loss=0.2113, acc=95.78%]
# Evaluating: 100%|██████████| 63/63 [00:59<00:00,  1.05it/s, loss=0.0005, acc=97.53%]
# Learning Rate: 0.000100
#
# Epoch 12 Results:
#    Train Loss: 0.1312 | Train Acc: 95.78%
#    Val Loss:   0.0976 | Val Acc:   97.53%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_12.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold1/fold_1/best_accuracy.pt
#  New best model! Val Acc: 97.53%
#
# ============================================================
# Epoch 13/30
# ============================================================
# Training: 100%|██████████| 248/248 [20:14<00:00,  4.90s/it, loss=0.1075, acc=96.23%]
# Training: 100%|██████████| 248/248 [20:14<00:00,  4.90s/it, loss=0.1075, acc=96.23%]
# Evaluating: 100%|██████████| 63/63 [00:56<00:00,  1.12it/s, loss=0.0004, acc=97.68%]
# Learning Rate: 0.000100
#
# Epoch 13 Results:
#    Train Loss: 0.1216 | Train Acc: 96.23%
#    Val Loss:   0.0937 | Val Acc:   97.68%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_13.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold1/fold_1/best_accuracy.pt
#  New best model! Val Acc: 97.68%
#
# ============================================================
# Epoch 14/30
# ============================================================
# Training: 100%|██████████| 248/248 [19:33<00:00,  4.73s/it, loss=0.0423, acc=96.19%]
# Training: 100%|██████████| 248/248 [19:33<00:00,  4.73s/it, loss=0.0423, acc=96.19%]
# Evaluating: 100%|██████████| 63/63 [00:47<00:00,  1.33it/s, loss=0.0005, acc=97.83%]
# Learning Rate: 0.000100
#
# Epoch 14 Results:
#    Train Loss: 0.1179 | Train Acc: 96.19%
#    Val Loss:   0.0931 | Val Acc:   97.83%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_14.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold1/fold_1/best_accuracy.pt
#  New best model! Val Acc: 97.83%
#
# ============================================================
# Epoch 15/30
# ============================================================
# Training: 100%|██████████| 248/248 [19:32<00:00,  4.73s/it, loss=0.0466, acc=96.43%]
# Training: 100%|██████████| 248/248 [19:32<00:00,  4.73s/it, loss=0.0466, acc=96.43%]
# Evaluating: 100%|██████████| 63/63 [00:49<00:00,  1.28it/s, loss=0.0004, acc=97.88%]
# Learning Rate: 0.000100
#
# Epoch 15 Results:
#    Train Loss: 0.1158 | Train Acc: 96.43%
#    Val Loss:   0.0909 | Val Acc:   97.88%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_15.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold1/fold_1/best_accuracy.pt
#  New best model! Val Acc: 97.88%
#
# ============================================================
# Epoch 16/30
# ============================================================
# Training: 100%|██████████| 248/248 [19:35<00:00,  4.74s/it, loss=0.1541, acc=96.36%]
# Training: 100%|██████████| 248/248 [19:35<00:00,  4.74s/it, loss=0.1541, acc=96.36%]
# Evaluating: 100%|██████████| 63/63 [00:55<00:00,  1.13it/s, loss=0.0002, acc=97.83%]
# Learning Rate: 0.000100
#
# Epoch 16 Results:
#    Train Loss: 0.1133 | Train Acc: 96.36%
#    Val Loss:   0.0891 | Val Acc:   97.83%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_16.pth
#
# ============================================================
# Epoch 17/30
# ============================================================
# Training: 100%|██████████| 248/248 [19:40<00:00,  4.76s/it, loss=0.1076, acc=96.84%]
# Training: 100%|██████████| 248/248 [19:40<00:00,  4.76s/it, loss=0.1076, acc=96.84%]
# Evaluating: 100%|██████████| 63/63 [00:55<00:00,  1.13it/s, loss=0.0002, acc=97.93%]
# Learning Rate: 0.000100
#
# Epoch 17 Results:
#    Train Loss: 0.1039 | Train Acc: 96.84%
#    Val Loss:   0.0858 | Val Acc:   97.93%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_17.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold1/fold_1/best_accuracy.pt
#  New best model! Val Acc: 97.93%
#
# ============================================================
# Epoch 18/30
# ============================================================
# Training: 100%|██████████| 248/248 [19:41<00:00,  4.77s/it, loss=0.0930, acc=96.93%]
# Training: 100%|██████████| 248/248 [19:41<00:00,  4.77s/it, loss=0.0930, acc=96.93%]
# Evaluating: 100%|██████████| 63/63 [00:55<00:00,  1.13it/s, loss=0.0001, acc=97.88%]
# Learning Rate: 0.000100
#
# Epoch 18 Results:
#    Train Loss: 0.0998 | Train Acc: 96.93%
#    Val Loss:   0.0842 | Val Acc:   97.88%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_18.pth
#
# ============================================================
# Epoch 19/30
# ============================================================
# Training: 100%|██████████| 248/248 [19:37<00:00,  4.75s/it, loss=0.0729, acc=96.91%]
# Training: 100%|██████████| 248/248 [19:37<00:00,  4.75s/it, loss=0.0729, acc=96.91%]
# Evaluating: 100%|██████████| 63/63 [00:47<00:00,  1.33it/s, loss=0.0000, acc=97.93%]
# Learning Rate: 0.000100
#
# Epoch 19 Results:
#    Train Loss: 0.1000 | Train Acc: 96.91%
#    Val Loss:   0.0875 | Val Acc:   97.93%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_19.pth
# WARNING: EarlyStopping counter: 1/7
#
# ============================================================
# Epoch 20/30
# ============================================================
# Training: 100%|██████████| 248/248 [19:32<00:00,  4.73s/it, loss=0.1716, acc=97.15%]
# Training: 100%|██████████| 248/248 [19:32<00:00,  4.73s/it, loss=0.1716, acc=97.15%]
# Evaluating: 100%|██████████| 63/63 [00:47<00:00,  1.33it/s, loss=0.0000, acc=98.04%]
# Learning Rate: 0.000010
#
# Epoch 20 Results:
#    Train Loss: 0.0978 | Train Acc: 97.15%
#    Val Loss:   0.0835 | Val Acc:   98.04%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_20.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold1/fold_1/best_accuracy.pt
#  New best model! Val Acc: 98.04%
#
# ============================================================
# Epoch 21/30
# ============================================================
# Training: 100%|██████████| 248/248 [19:33<00:00,  4.73s/it, loss=0.0357, acc=96.64%]
# Training: 100%|██████████| 248/248 [19:33<00:00,  4.73s/it, loss=0.0357, acc=96.64%]
# Evaluating: 100%|██████████| 63/63 [00:50<00:00,  1.24it/s, loss=0.0001, acc=97.98%]
# Learning Rate: 0.000010
#
# Epoch 21 Results:
#    Train Loss: 0.1030 | Train Acc: 96.64%
#    Val Loss:   0.0861 | Val Acc:   97.98%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_21.pth
# WARNING: EarlyStopping counter: 1/7
#
# ============================================================
# Epoch 22/30
# ============================================================
# Training: 100%|██████████| 248/248 [19:41<00:00,  4.76s/it, loss=0.0886, acc=96.74%]
# Training: 100%|██████████| 248/248 [19:41<00:00,  4.76s/it, loss=0.0886, acc=96.74%]
# Evaluating: 100%|██████████| 63/63 [00:55<00:00,  1.13it/s, loss=0.0001, acc=97.83%]
# Learning Rate: 0.000010
#
# Epoch 22 Results:
#    Train Loss: 0.1032 | Train Acc: 96.74%
#    Val Loss:   0.0867 | Val Acc:   97.83%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_22.pth
# WARNING: EarlyStopping counter: 2/7
#
# ============================================================
# Epoch 23/30
# ============================================================
# Training: 100%|██████████| 248/248 [19:41<00:00,  4.76s/it, loss=0.0716, acc=96.96%]
# Training: 100%|██████████| 248/248 [19:41<00:00,  4.76s/it, loss=0.0716, acc=96.96%]
# Evaluating: 100%|██████████| 63/63 [00:55<00:00,  1.13it/s, loss=0.0001, acc=97.93%]
# Learning Rate: 0.000010
#
# Epoch 23 Results:
#    Train Loss: 0.1016 | Train Acc: 96.96%
#    Val Loss:   0.0838 | Val Acc:   97.93%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_23.pth
# WARNING: EarlyStopping counter: 3/7
#
# ============================================================
# Epoch 24/30
# ============================================================
# Training: 100%|██████████| 248/248 [4:20:09<00:00, 62.94s/it, loss=0.0924, acc=96.85%]
# Training: 100%|██████████| 248/248 [4:20:09<00:00, 62.94s/it, loss=0.0924, acc=96.85%]
# Evaluating: 100%|██████████| 63/63 [01:08<00:00,  1.09s/it, loss=0.0001, acc=97.93%]
# Learning Rate: 0.000010
#
# Epoch 24 Results:
#    Train Loss: 0.0964 | Train Acc: 96.85%
#    Val Loss:   0.0857 | Val Acc:   97.93%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_24.pth
# WARNING: EarlyStopping counter: 4/7
#
# ============================================================
# Epoch 25/30
# ============================================================
# Training: 100%|██████████| 248/248 [20:15<00:00,  4.90s/it, loss=0.0722, acc=96.69%]
# Training: 100%|██████████| 248/248 [20:15<00:00,  4.90s/it, loss=0.0722, acc=96.69%]
# Evaluating: 100%|██████████| 63/63 [00:49<00:00,  1.28it/s, loss=0.0001, acc=98.09%]
# Learning Rate: 0.000010
#
# Epoch 25 Results:
#    Train Loss: 0.0977 | Train Acc: 96.69%
#    Val Loss:   0.0846 | Val Acc:   98.09%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_25.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold1/fold_1/best_accuracy.pt
#  New best model! Val Acc: 98.09%
# WARNING: EarlyStopping counter: 5/7
#
# ============================================================
# Epoch 26/30
# ============================================================
# Training: 100%|██████████| 248/248 [19:31<00:00,  4.72s/it, loss=0.0653, acc=97.10%]
# Training: 100%|██████████| 248/248 [19:31<00:00,  4.72s/it, loss=0.0653, acc=97.10%]
# Evaluating: 100%|██████████| 63/63 [00:46<00:00,  1.35it/s, loss=0.0001, acc=97.93%]
# Learning Rate: 0.000010
#
# Epoch 26 Results:
#    Train Loss: 0.0936 | Train Acc: 97.10%
#    Val Loss:   0.0845 | Val Acc:   97.93%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_26.pth
# WARNING: EarlyStopping counter: 6/7
#
# ============================================================
# Epoch 27/30
# ============================================================
# Training: 100%|██████████| 248/248 [19:33<00:00,  4.73s/it, loss=0.1263, acc=97.15%]
# Training: 100%|██████████| 248/248 [19:33<00:00,  4.73s/it, loss=0.1263, acc=97.15%]
# Evaluating: 100%|██████████| 63/63 [00:47<00:00,  1.33it/s, loss=0.0001, acc=97.98%]
# Learning Rate: 0.000010
#
# Epoch 27 Results:
#    Train Loss: 0.0922 | Train Acc: 97.15%
#    Val Loss:   0.0845 | Val Acc:   97.98%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold1/fold_1/checkpoint_epoch_27.pth
# WARNING: EarlyStopping counter: 7/7
# SUCCESS: Early stopping triggered at epoch 27
# Best validation loss was 0.0835 at epoch 20
#
# ============================================================
# SUCCESS: Training stopped early at epoch 27/30
# Best Validation Accuracy: 98.09%
# ============================================================
#
# Fold 1 - Best Acc: 98.09% (stopped at epoch 27)
#
# ============================================================
# FOLD 2/5
# ============================================================
# Created SGD optimizer: lr=0.001, momentum=0.8, weight_decay=0.0001
# Training on: cpu
#
# ============================================================
# Epoch 1/30
# ============================================================
# Training: 100%|██████████| 249/249 [19:52<00:00,  4.79s/it, loss=1.1267, acc=54.95%]
# Training: 100%|██████████| 249/249 [19:52<00:00,  4.79s/it, loss=1.1267, acc=54.95%]
# Evaluating: 100%|██████████| 62/62 [00:53<00:00,  1.16it/s, loss=0.7961, acc=67.49%]
# Learning Rate: 0.001000
#
# Epoch 1 Results:
#    Train Loss: 1.0383 | Train Acc: 54.95%
#    Val Loss:   0.8045 | Val Acc:   67.49%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_1.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold2/fold_1/best_accuracy.pt
#  New best model! Val Acc: 67.49%
#
# ============================================================
# Epoch 2/30
# ============================================================
# Training: 100%|██████████| 249/249 [21:44<00:00,  5.24s/it, loss=1.2392, acc=68.39%]
# Training: 100%|██████████| 249/249 [21:44<00:00,  5.24s/it, loss=1.2392, acc=68.39%]
# Evaluating: 100%|██████████| 62/62 [01:05<00:00,  1.06s/it, loss=0.8421, acc=72.38%]
# Learning Rate: 0.001000
#
# Epoch 2 Results:
#    Train Loss: 0.7893 | Train Acc: 68.39%
#    Val Loss:   0.6901 | Val Acc:   72.38%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_2.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold2/fold_1/best_accuracy.pt
#  New best model! Val Acc: 72.38%
#
# ============================================================
# Epoch 3/30
# ============================================================
# Training: 100%|██████████| 249/249 [23:57<00:00,  5.77s/it, loss=1.9539, acc=73.71%]
# Training: 100%|██████████| 249/249 [23:57<00:00,  5.77s/it, loss=1.9539, acc=73.71%]
# Evaluating: 100%|██████████| 62/62 [01:06<00:00,  1.08s/it, loss=0.9345, acc=77.37%]
# Learning Rate: 0.001000
#
# Epoch 3 Results:
#    Train Loss: 0.6715 | Train Acc: 73.71%
#    Val Loss:   0.5687 | Val Acc:   77.37%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_3.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold2/fold_1/best_accuracy.pt
#  New best model! Val Acc: 77.37%
#
# ============================================================
# Epoch 4/30
# ============================================================
# Training: 100%|██████████| 249/249 [21:45<00:00,  5.24s/it, loss=1.7384, acc=77.89%]
# Training: 100%|██████████| 249/249 [21:45<00:00,  5.24s/it, loss=1.7384, acc=77.89%]
# Evaluating: 100%|██████████| 62/62 [01:01<00:00,  1.01it/s, loss=1.1213, acc=80.59%]
# Learning Rate: 0.001000
#
# Epoch 4 Results:
#    Train Loss: 0.5755 | Train Acc: 77.89%
#    Val Loss:   0.4981 | Val Acc:   80.59%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_4.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold2/fold_1/best_accuracy.pt
#  New best model! Val Acc: 80.59%
#
# ============================================================
# Epoch 5/30
# ============================================================
# Training: 100%|██████████| 249/249 [21:17<00:00,  5.13s/it, loss=1.0620, acc=81.43%]
# Training: 100%|██████████| 249/249 [21:17<00:00,  5.13s/it, loss=1.0620, acc=81.43%]
# Evaluating: 100%|██████████| 62/62 [01:01<00:00,  1.01it/s, loss=1.0969, acc=84.48%]
# Learning Rate: 0.001000
#
# Epoch 5 Results:
#    Train Loss: 0.4899 | Train Acc: 81.43%
#    Val Loss:   0.3995 | Val Acc:   84.48%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_5.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold2/fold_1/best_accuracy.pt
#  New best model! Val Acc: 84.48%
#
# ============================================================
# Epoch 6/30
# ============================================================
# Training: 100%|██████████| 249/249 [21:58<00:00,  5.30s/it, loss=1.9741, acc=85.01%]
# Training: 100%|██████████| 249/249 [21:58<00:00,  5.30s/it, loss=1.9741, acc=85.01%]
# Evaluating: 100%|██████████| 62/62 [01:08<00:00,  1.11s/it, loss=1.3470, acc=87.35%]
# Learning Rate: 0.001000
#
# Epoch 6 Results:
#    Train Loss: 0.4053 | Train Acc: 85.01%
#    Val Loss:   0.3547 | Val Acc:   87.35%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_6.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold2/fold_1/best_accuracy.pt
#  New best model! Val Acc: 87.35%
#
# ============================================================
# Epoch 7/30
# ============================================================
# Training: 100%|██████████| 249/249 [23:07<00:00,  5.57s/it, loss=2.0044, acc=87.53%]
# Training: 100%|██████████| 249/249 [23:07<00:00,  5.57s/it, loss=2.0044, acc=87.53%]
# Evaluating: 100%|██████████| 62/62 [01:05<00:00,  1.06s/it, loss=1.4229, acc=89.11%]
# Learning Rate: 0.001000
#
# Epoch 7 Results:
#    Train Loss: 0.3278 | Train Acc: 87.53%
#    Val Loss:   0.2986 | Val Acc:   89.11%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_7.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold2/fold_1/best_accuracy.pt
#  New best model! Val Acc: 89.11%
#
# ============================================================
# Epoch 8/30
# ============================================================
# Training: 100%|██████████| 249/249 [21:38<00:00,  5.21s/it, loss=1.1441, acc=89.53%]
# Training: 100%|██████████| 249/249 [21:38<00:00,  5.21s/it, loss=1.1441, acc=89.53%]
# Evaluating: 100%|██████████| 62/62 [01:01<00:00,  1.00it/s, loss=1.5092, acc=92.34%]
# Learning Rate: 0.001000
#
# Epoch 8 Results:
#    Train Loss: 0.2836 | Train Acc: 89.53%
#    Val Loss:   0.2378 | Val Acc:   92.34%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_8.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold2/fold_1/best_accuracy.pt
#  New best model! Val Acc: 92.34%
#
# ============================================================
# Epoch 9/30
# ============================================================
# Training: 100%|██████████| 249/249 [20:56<00:00,  5.05s/it, loss=1.1573, acc=91.45%]
# Training: 100%|██████████| 249/249 [20:56<00:00,  5.05s/it, loss=1.1573, acc=91.45%]
# Evaluating: 100%|██████████| 62/62 [00:58<00:00,  1.06it/s, loss=1.2543, acc=92.54%]
# Learning Rate: 0.001000
#
# Epoch 9 Results:
#    Train Loss: 0.2464 | Train Acc: 91.45%
#    Val Loss:   0.2235 | Val Acc:   92.54%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_9.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold2/fold_1/best_accuracy.pt
#  New best model! Val Acc: 92.54%
#
# ============================================================
# Epoch 10/30
# ============================================================
# Training: 100%|██████████| 249/249 [20:39<00:00,  4.98s/it, loss=2.6184, acc=92.87%]
# Training: 100%|██████████| 249/249 [20:39<00:00,  4.98s/it, loss=2.6184, acc=92.87%]
# Evaluating: 100%|██████████| 62/62 [00:49<00:00,  1.25it/s, loss=1.5870, acc=95.56%]
# Learning Rate: 0.000100
#
# Epoch 10 Results:
#    Train Loss: 0.2047 | Train Acc: 92.87%
#    Val Loss:   0.1469 | Val Acc:   95.56%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_10.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold2/fold_1/best_accuracy.pt
#  New best model! Val Acc: 95.56%
#
# ============================================================
# Epoch 11/30
# ============================================================
# Training: 100%|██████████| 249/249 [21:13<00:00,  5.11s/it, loss=1.7167, acc=94.99%]
# Training: 100%|██████████| 249/249 [21:13<00:00,  5.11s/it, loss=1.7167, acc=94.99%]
# Evaluating: 100%|██████████| 62/62 [01:05<00:00,  1.05s/it, loss=1.7779, acc=95.56%]
# Learning Rate: 0.000100
#
# Epoch 11 Results:
#    Train Loss: 0.1554 | Train Acc: 94.99%
#    Val Loss:   0.1394 | Val Acc:   95.56%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_11.pth
#
# ============================================================
# Epoch 12/30
# ============================================================
# Training: 100%|██████████| 249/249 [22:42<00:00,  5.47s/it, loss=0.7713, acc=95.58%]
# Training: 100%|██████████| 249/249 [22:42<00:00,  5.47s/it, loss=0.7713, acc=95.58%]
# Evaluating: 100%|██████████| 62/62 [01:06<00:00,  1.07s/it, loss=1.7090, acc=96.47%]
# Learning Rate: 0.000100
#
# Epoch 12 Results:
#    Train Loss: 0.1354 | Train Acc: 95.58%
#    Val Loss:   0.1277 | Val Acc:   96.47%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_12.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold2/fold_1/best_accuracy.pt
#  New best model! Val Acc: 96.47%
#
# ============================================================
# Epoch 13/30
# ============================================================
# Training: 100%|██████████| 249/249 [24:23<00:00,  5.88s/it, loss=1.8645, acc=95.80%]
# Training: 100%|██████████| 249/249 [24:23<00:00,  5.88s/it, loss=1.8645, acc=95.80%]
# Evaluating: 100%|██████████| 62/62 [01:12<00:00,  1.16s/it, loss=1.6899, acc=95.97%]
# Learning Rate: 0.000100
#
# Epoch 13 Results:
#    Train Loss: 0.1271 | Train Acc: 95.80%
#    Val Loss:   0.1289 | Val Acc:   95.97%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_13.pth
# WARNING: EarlyStopping counter: 1/7
#
# ============================================================
# Epoch 14/30
# ============================================================
# Training: 100%|██████████| 249/249 [23:09<00:00,  5.58s/it, loss=1.3775, acc=96.37%]
# Training: 100%|██████████| 249/249 [23:09<00:00,  5.58s/it, loss=1.3775, acc=96.37%]
# Evaluating: 100%|██████████| 62/62 [01:08<00:00,  1.10s/it, loss=1.6493, acc=96.42%]
# Learning Rate: 0.000100
#
# Epoch 14 Results:
#    Train Loss: 0.1206 | Train Acc: 96.37%
#    Val Loss:   0.1251 | Val Acc:   96.42%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_14.pth
#
# ============================================================
# Epoch 15/30
# ============================================================
# Training: 100%|██████████| 249/249 [23:29<00:00,  5.66s/it, loss=2.4439, acc=96.56%]
# Training: 100%|██████████| 249/249 [23:29<00:00,  5.66s/it, loss=2.4439, acc=96.56%]
# Evaluating: 100%|██████████| 62/62 [01:17<00:00,  1.24s/it, loss=1.6624, acc=96.98%]
# Learning Rate: 0.000100
#
# Epoch 15 Results:
#    Train Loss: 0.1145 | Train Acc: 96.56%
#    Val Loss:   0.1119 | Val Acc:   96.98%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_15.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold2/fold_1/best_accuracy.pt
#  New best model! Val Acc: 96.98%
#
# ============================================================
# Epoch 16/30
# ============================================================
# Training: 100%|██████████| 249/249 [24:18<00:00,  5.86s/it, loss=0.9060, acc=96.36%]
# Training: 100%|██████████| 249/249 [24:18<00:00,  5.86s/it, loss=0.9060, acc=96.36%]
# Evaluating: 100%|██████████| 62/62 [01:11<00:00,  1.16s/it, loss=1.6934, acc=96.77%]
# Learning Rate: 0.000100
#
# Epoch 16 Results:
#    Train Loss: 0.1151 | Train Acc: 96.36%
#    Val Loss:   0.1145 | Val Acc:   96.77%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_16.pth
# WARNING: EarlyStopping counter: 1/7
#
# ============================================================
# Epoch 17/30
# ============================================================
# Training: 100%|██████████| 249/249 [24:19<00:00,  5.86s/it, loss=2.3604, acc=96.86%]
# Training: 100%|██████████| 249/249 [24:19<00:00,  5.86s/it, loss=2.3604, acc=96.86%]
# Evaluating: 100%|██████████| 62/62 [01:11<00:00,  1.15s/it, loss=1.6222, acc=97.23%]
# Learning Rate: 0.000100
#
# Epoch 17 Results:
#    Train Loss: 0.1104 | Train Acc: 96.86%
#    Val Loss:   0.1093 | Val Acc:   97.23%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_17.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold2/fold_1/best_accuracy.pt
#  New best model! Val Acc: 97.23%
#
# ============================================================
# Epoch 18/30
# ============================================================
# Training: 100%|██████████| 249/249 [24:50<00:00,  5.99s/it, loss=2.0470, acc=96.61%]
# Training: 100%|██████████| 249/249 [24:50<00:00,  5.99s/it, loss=2.0470, acc=96.61%]
# Evaluating: 100%|██████████| 62/62 [01:13<00:00,  1.19s/it, loss=1.6396, acc=97.28%]
# Learning Rate: 0.000100
#
# Epoch 18 Results:
#    Train Loss: 0.1054 | Train Acc: 96.61%
#    Val Loss:   0.1099 | Val Acc:   97.28%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_18.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold2/fold_1/best_accuracy.pt
#  New best model! Val Acc: 97.28%
# WARNING: EarlyStopping counter: 1/7
#
# ============================================================
# Epoch 19/30
# ============================================================
# Training: 100%|██████████| 249/249 [24:39<00:00,  5.94s/it, loss=1.7002, acc=96.59%]
# Training: 100%|██████████| 249/249 [24:39<00:00,  5.94s/it, loss=1.7002, acc=96.59%]
# Evaluating: 100%|██████████| 62/62 [01:04<00:00,  1.04s/it, loss=1.7025, acc=97.03%]
# Learning Rate: 0.000100
#
# Epoch 19 Results:
#    Train Loss: 0.1070 | Train Acc: 96.59%
#    Val Loss:   0.1100 | Val Acc:   97.03%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_19.pth
# WARNING: EarlyStopping counter: 2/7
#
# ============================================================
# Epoch 20/30
# ============================================================
# Training: 100%|██████████| 249/249 [20:39<00:00,  4.98s/it, loss=1.2797, acc=96.57%]
# Training: 100%|██████████| 249/249 [20:39<00:00,  4.98s/it, loss=1.2797, acc=96.57%]
# Evaluating: 100%|██████████| 62/62 [00:56<00:00,  1.09it/s, loss=1.8820, acc=96.62%]
# Learning Rate: 0.000010
#
# Epoch 20 Results:
#    Train Loss: 0.1040 | Train Acc: 96.57%
#    Val Loss:   0.1222 | Val Acc:   96.62%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_20.pth
# WARNING: EarlyStopping counter: 3/7
#
# ============================================================
# Epoch 21/30
# ============================================================
# Training: 100%|██████████| 249/249 [20:19<00:00,  4.90s/it, loss=0.7815, acc=96.95%]
# Training: 100%|██████████| 249/249 [20:19<00:00,  4.90s/it, loss=0.7815, acc=96.95%]
# Evaluating: 100%|██████████| 62/62 [00:57<00:00,  1.08it/s, loss=1.9245, acc=96.82%]
# Learning Rate: 0.000010
#
# Epoch 21 Results:
#    Train Loss: 0.0980 | Train Acc: 96.95%
#    Val Loss:   0.1102 | Val Acc:   96.82%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_21.pth
# WARNING: EarlyStopping counter: 4/7
#
# ============================================================
# Epoch 22/30
# ============================================================
# Training: 100%|██████████| 249/249 [19:54<00:00,  4.80s/it, loss=0.5861, acc=96.76%]
# Training: 100%|██████████| 249/249 [19:54<00:00,  4.80s/it, loss=0.5861, acc=96.76%]
# Evaluating: 100%|██████████| 62/62 [00:48<00:00,  1.29it/s, loss=1.8611, acc=96.32%]
# Learning Rate: 0.000010
#
# Epoch 22 Results:
#    Train Loss: 0.0995 | Train Acc: 96.76%
#    Val Loss:   0.1232 | Val Acc:   96.32%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_22.pth
# WARNING: EarlyStopping counter: 5/7
#
# ============================================================
# Epoch 23/30
# ============================================================
# Training: 100%|██████████| 249/249 [19:55<00:00,  4.80s/it, loss=2.5592, acc=96.80%]
# Training: 100%|██████████| 249/249 [19:55<00:00,  4.80s/it, loss=2.5592, acc=96.80%]
# Evaluating: 100%|██████████| 62/62 [00:58<00:00,  1.05it/s, loss=1.8026, acc=97.18%]
# Learning Rate: 0.000010
#
# Epoch 23 Results:
#    Train Loss: 0.0984 | Train Acc: 96.80%
#    Val Loss:   0.1074 | Val Acc:   97.18%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_23.pth
#
# ============================================================
# Epoch 24/30
# ============================================================
# Training: 100%|██████████| 249/249 [20:53<00:00,  5.03s/it, loss=1.7948, acc=96.84%]
# Training: 100%|██████████| 249/249 [20:53<00:00,  5.03s/it, loss=1.7948, acc=96.84%]
# Evaluating: 100%|██████████| 62/62 [01:01<00:00,  1.00it/s, loss=1.8582, acc=96.62%]
# Learning Rate: 0.000010
#
# Epoch 24 Results:
#    Train Loss: 0.1004 | Train Acc: 96.84%
#    Val Loss:   0.1178 | Val Acc:   96.62%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_24.pth
# WARNING: EarlyStopping counter: 1/7
#
# ============================================================
# Epoch 25/30
# ============================================================
# Training: 100%|██████████| 249/249 [21:48<00:00,  5.25s/it, loss=1.4202, acc=97.13%]
# Training: 100%|██████████| 249/249 [21:48<00:00,  5.25s/it, loss=1.4202, acc=97.13%]
# Evaluating: 100%|██████████| 62/62 [01:06<00:00,  1.08s/it, loss=1.7080, acc=97.38%]
# Learning Rate: 0.000010
#
# Epoch 25 Results:
#    Train Loss: 0.0946 | Train Acc: 97.13%
#    Val Loss:   0.0969 | Val Acc:   97.38%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_25.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold2/fold_1/best_accuracy.pt
#  New best model! Val Acc: 97.38%
#
# ============================================================
# Epoch 26/30
# ============================================================
# Training: 100%|██████████| 249/249 [30:58<00:00,  7.46s/it, loss=0.6526, acc=96.84%]
# Training: 100%|██████████| 249/249 [30:58<00:00,  7.46s/it, loss=0.6526, acc=96.84%]
# Evaluating: 100%|██████████| 62/62 [01:43<00:00,  1.68s/it, loss=1.6713, acc=97.23%]
# Learning Rate: 0.000010
#
# Epoch 26 Results:
#    Train Loss: 0.1005 | Train Acc: 96.84%
#    Val Loss:   0.0984 | Val Acc:   97.23%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_26.pth
# WARNING: EarlyStopping counter: 1/7
#
# ============================================================
# Epoch 27/30
# ============================================================
# Training: 100%|██████████| 249/249 [42:10<00:00, 10.16s/it, loss=0.9296, acc=97.08%]
# Training: 100%|██████████| 249/249 [42:10<00:00, 10.16s/it, loss=0.9296, acc=97.08%]
# Evaluating: 100%|██████████| 62/62 [01:37<00:00,  1.57s/it, loss=1.6554, acc=97.48%]
# Learning Rate: 0.000010
#
# Epoch 27 Results:
#    Train Loss: 0.1018 | Train Acc: 97.08%
#    Val Loss:   0.0971 | Val Acc:   97.48%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_27.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold2/fold_1/best_accuracy.pt
#  New best model! Val Acc: 97.48%
# WARNING: EarlyStopping counter: 2/7
#
# ============================================================
# Epoch 28/30
# ============================================================
# Training: 100%|██████████| 249/249 [41:17<00:00,  9.95s/it, loss=1.8199, acc=96.86%]
# Training: 100%|██████████| 249/249 [41:17<00:00,  9.95s/it, loss=1.8199, acc=96.86%]
# Evaluating: 100%|██████████| 62/62 [01:51<00:00,  1.80s/it, loss=1.7855, acc=97.58%]
# Learning Rate: 0.000010
#
# Epoch 28 Results:
#    Train Loss: 0.0962 | Train Acc: 96.86%
#    Val Loss:   0.0998 | Val Acc:   97.58%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_28.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold2/fold_1/best_accuracy.pt
#  New best model! Val Acc: 97.58%
# WARNING: EarlyStopping counter: 3/7
#
# ============================================================
# Epoch 29/30
# ============================================================
# Training: 100%|██████████| 249/249 [39:48<00:00,  9.59s/it, loss=1.0195, acc=96.66%]
# Training: 100%|██████████| 249/249 [39:48<00:00,  9.59s/it, loss=1.0195, acc=96.66%]
# Evaluating: 100%|██████████| 62/62 [01:36<00:00,  1.55s/it, loss=1.7982, acc=97.33%]
# Learning Rate: 0.000010
#
# Epoch 29 Results:
#    Train Loss: 0.1023 | Train Acc: 96.66%
#    Val Loss:   0.1032 | Val Acc:   97.33%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_29.pth
# WARNING: EarlyStopping counter: 4/7
#
# ============================================================
# Epoch 30/30
# ============================================================
# Training: 100%|██████████| 249/249 [36:50<00:00,  8.88s/it, loss=1.1556, acc=97.08%]
# Training: 100%|██████████| 249/249 [36:50<00:00,  8.88s/it, loss=1.1556, acc=97.08%]
# Evaluating: 100%|██████████| 62/62 [01:23<00:00,  1.35s/it, loss=1.8190, acc=96.72%]
# Learning Rate: 0.000001
#
# Epoch 30 Results:
#    Train Loss: 0.0930 | Train Acc: 97.08%
#    Val Loss:   0.1076 | Val Acc:   96.72%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold2/fold_1/checkpoint_epoch_30.pth
# WARNING: EarlyStopping counter: 5/7
#
# ============================================================
# SUCCESS: Training Complete!
# Completed all 30 epochs
# Best Validation Accuracy: 97.58%
# ============================================================
#
# Fold 2 - Best Acc: 97.58% (stopped at epoch 30)
#
# ============================================================
# FOLD 3/5
# ============================================================
# Created SGD optimizer: lr=0.001, momentum=0.8, weight_decay=0.0001
# Training on: cpu
#
# ============================================================
# Epoch 1/30
# ============================================================
# Training: 100%|██████████| 249/249 [36:13<00:00,  8.73s/it, loss=1.8023, acc=54.98%]
# Training: 100%|██████████| 249/249 [36:13<00:00,  8.73s/it, loss=1.8023, acc=54.98%]
# Evaluating: 100%|██████████| 62/62 [01:28<00:00,  1.43s/it, loss=1.0733, acc=64.52%]
# Learning Rate: 0.001000
#
# Epoch 1 Results:
#    Train Loss: 1.0362 | Train Acc: 54.98%
#    Val Loss:   0.8564 | Val Acc:   64.52%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold3/fold_1/checkpoint_epoch_1.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold3/fold_1/best_accuracy.pt
#  New best model! Val Acc: 64.52%
#
# ============================================================
# Epoch 2/30
# ============================================================
# Training: 100%|██████████| 249/249 [36:18<00:00,  8.75s/it, loss=2.3363, acc=67.78%]
# Training: 100%|██████████| 249/249 [36:18<00:00,  8.75s/it, loss=2.3363, acc=67.78%]
# Evaluating: 100%|██████████| 62/62 [01:26<00:00,  1.40s/it, loss=1.0478, acc=70.67%]
# Learning Rate: 0.001000
#
# Epoch 2 Results:
#    Train Loss: 0.7987 | Train Acc: 67.78%
#    Val Loss:   0.7128 | Val Acc:   70.67%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold3/fold_1/checkpoint_epoch_2.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold3/fold_1/best_accuracy.pt
#  New best model! Val Acc: 70.67%
#
# ============================================================
# Epoch 3/30
# ============================================================
# Training: 100%|██████████| 249/249 [36:02<00:00,  8.68s/it, loss=1.0696, acc=73.55%]
# Training: 100%|██████████| 249/249 [36:02<00:00,  8.68s/it, loss=1.0696, acc=73.55%]
# Evaluating: 100%|██████████| 62/62 [01:39<00:00,  1.60s/it, loss=0.8850, acc=76.41%]
# Learning Rate: 0.001000
#
# Epoch 3 Results:
#    Train Loss: 0.6795 | Train Acc: 73.55%
#    Val Loss:   0.6183 | Val Acc:   76.41%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold3/fold_1/checkpoint_epoch_3.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold3/fold_1/best_accuracy.pt
#  New best model! Val Acc: 76.41%
#
# ============================================================
# Epoch 4/30
# ============================================================
# Training: 100%|██████████| 249/249 [38:30<00:00,  9.28s/it, loss=1.4211, acc=77.52%]
# Training: 100%|██████████| 249/249 [38:30<00:00,  9.28s/it, loss=1.4211, acc=77.52%]
# Evaluating: 100%|██████████| 62/62 [01:35<00:00,  1.54s/it, loss=1.0092, acc=82.21%]
# Learning Rate: 0.001000
#
# Epoch 4 Results:
#    Train Loss: 0.5847 | Train Acc: 77.52%
#    Val Loss:   0.4949 | Val Acc:   82.21%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold3/fold_1/checkpoint_epoch_4.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold3/fold_1/best_accuracy.pt
#  New best model! Val Acc: 82.21%
#
# ============================================================
# Epoch 5/30
# ============================================================
# Training: 100%|██████████| 249/249 [37:03<00:00,  8.93s/it, loss=1.3050, acc=81.53%]
# Training: 100%|██████████| 249/249 [37:03<00:00,  8.93s/it, loss=1.3050, acc=81.53%]
# Evaluating: 100%|██████████| 62/62 [01:26<00:00,  1.40s/it, loss=0.9136, acc=85.84%]
# Learning Rate: 0.001000
#
# Epoch 5 Results:
#    Train Loss: 0.4850 | Train Acc: 81.53%
#    Val Loss:   0.3829 | Val Acc:   85.84%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold3/fold_1/checkpoint_epoch_5.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold3/fold_1/best_accuracy.pt
#  New best model! Val Acc: 85.84%
#
# ============================================================
# Epoch 6/30
# ============================================================
# Training: 100%|██████████| 249/249 [36:53<00:00,  8.89s/it, loss=0.8915, acc=84.36%]
# Training: 100%|██████████| 249/249 [36:53<00:00,  8.89s/it, loss=0.8915, acc=84.36%]
# Evaluating: 100%|██████████| 62/62 [01:31<00:00,  1.48s/it, loss=0.9073, acc=88.46%]
# Learning Rate: 0.001000
#
# Epoch 6 Results:
#    Train Loss: 0.4156 | Train Acc: 84.36%
#    Val Loss:   0.3190 | Val Acc:   88.46%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold3/fold_1/checkpoint_epoch_6.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold3/fold_1/best_accuracy.pt
#  New best model! Val Acc: 88.46%
#
# ============================================================
# Epoch 7/30
# ============================================================
# Training: 100%|██████████| 249/249 [36:32<00:00,  8.81s/it, loss=0.7434, acc=88.23%]
# Training: 100%|██████████| 249/249 [36:32<00:00,  8.81s/it, loss=0.7434, acc=88.23%]
# Evaluating: 100%|██████████| 62/62 [01:38<00:00,  1.59s/it, loss=1.1157, acc=92.04%]
# Learning Rate: 0.001000
#
# Epoch 7 Results:
#    Train Loss: 0.3301 | Train Acc: 88.23%
#    Val Loss:   0.2392 | Val Acc:   92.04%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold3/fold_1/checkpoint_epoch_7.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold3/fold_1/best_accuracy.pt
#  New best model! Val Acc: 92.04%
#
# ============================================================
# Epoch 8/30
# ============================================================
# Training: 100%|██████████| 249/249 [36:48<00:00,  8.87s/it, loss=1.3189, acc=89.81%]
# Training: 100%|██████████| 249/249 [36:48<00:00,  8.87s/it, loss=1.3189, acc=89.81%]
# Evaluating: 100%|██████████| 62/62 [01:34<00:00,  1.52s/it, loss=1.3763, acc=92.24%]
# Learning Rate: 0.001000
#
# Epoch 8 Results:
#    Train Loss: 0.2916 | Train Acc: 89.81%
#    Val Loss:   0.2478 | Val Acc:   92.24%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold3/fold_1/checkpoint_epoch_8.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold3/fold_1/best_accuracy.pt
#  New best model! Val Acc: 92.24%
# WARNING: EarlyStopping counter: 1/7
#
# ============================================================
# Epoch 9/30
# ============================================================
# Training: 100%|██████████| 249/249 [37:18<00:00,  8.99s/it, loss=2.6322, acc=91.67%]
# Training: 100%|██████████| 249/249 [37:18<00:00,  8.99s/it, loss=2.6322, acc=91.67%]
# Evaluating: 100%|██████████| 62/62 [01:31<00:00,  1.47s/it, loss=1.2807, acc=93.50%]
# Learning Rate: 0.001000
#
# Epoch 9 Results:
#    Train Loss: 0.2393 | Train Acc: 91.67%
#    Val Loss:   0.1976 | Val Acc:   93.50%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold3/fold_1/checkpoint_epoch_9.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold3/fold_1/best_accuracy.pt
#  New best model! Val Acc: 93.50%
#
# ============================================================
# Epoch 10/30
# ============================================================
# Training: 100%|██████████| 249/249 [37:27<00:00,  9.02s/it, loss=1.1872, acc=93.06%]
# Training: 100%|██████████| 249/249 [37:27<00:00,  9.02s/it, loss=1.1872, acc=93.06%]
# Evaluating: 100%|██████████| 62/62 [01:27<00:00,  1.42s/it, loss=0.9655, acc=96.32%]
# Learning Rate: 0.000100
#
# Epoch 10 Results:
#    Train Loss: 0.2053 | Train Acc: 93.06%
#    Val Loss:   0.1337 | Val Acc:   96.32%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold3/fold_1/checkpoint_epoch_10.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold3/fold_1/best_accuracy.pt
#  New best model! Val Acc: 96.32%
#
# ============================================================
# Epoch 11/30
# ============================================================
# Training: 100%|██████████| 249/249 [36:32<00:00,  8.80s/it, loss=0.8420, acc=94.85%]
# Training: 100%|██████████| 249/249 [36:32<00:00,  8.80s/it, loss=0.8420, acc=94.85%]
# Evaluating: 100%|██████████| 62/62 [01:38<00:00,  1.59s/it, loss=1.1181, acc=96.88%]
# Learning Rate: 0.000100
#
# Epoch 11 Results:
#    Train Loss: 0.1563 | Train Acc: 94.85%
#    Val Loss:   0.1158 | Val Acc:   96.88%
# ...
# Training: 100%|██████████| 249/249 [38:28<00:00,  9.27s/it, loss=2.1875, acc=77.77%]
# Evaluating: 100%|██████████| 62/62 [01:39<00:00,  1.60s/it, loss=1.1230, acc=82.66%]
# Learning Rate: 0.001000
#
# Epoch 4 Results:
#    Train Loss: 0.5757 | Train Acc: 77.77%
#    Val Loss:   0.4715 | Val Acc:   82.66%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_4.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold5/fold_1/best_accuracy.pt
#  New best model! Val Acc: 82.66%
#
# ============================================================
# Epoch 5/30
# ============================================================
# Training: 100%|██████████| 249/249 [40:23<00:00,  9.73s/it, loss=2.5853, acc=81.73%]
# Training: 100%|██████████| 249/249 [40:23<00:00,  9.73s/it, loss=2.5853, acc=81.73%]
# Evaluating: 100%|██████████| 62/62 [01:35<00:00,  1.54s/it, loss=1.5419, acc=86.19%]
# Learning Rate: 0.001000
#
# Epoch 5 Results:
#    Train Loss: 0.4782 | Train Acc: 81.73%
#    Val Loss:   0.3743 | Val Acc:   86.19%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_5.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold5/fold_1/best_accuracy.pt
#  New best model! Val Acc: 86.19%
#
# ============================================================
# Epoch 6/30
# ============================================================
# Training: 100%|██████████| 249/249 [40:57<00:00,  9.87s/it, loss=1.0862, acc=85.75%]
# Training: 100%|██████████| 249/249 [40:57<00:00,  9.87s/it, loss=1.0862, acc=85.75%]
# Evaluating: 100%|██████████| 62/62 [01:48<00:00,  1.75s/it, loss=1.3113, acc=88.86%]
# Learning Rate: 0.001000
#
# Epoch 6 Results:
#    Train Loss: 0.3955 | Train Acc: 85.75%
#    Val Loss:   0.3180 | Val Acc:   88.86%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_6.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold5/fold_1/best_accuracy.pt
#  New best model! Val Acc: 88.86%
#
# ============================================================
# Epoch 7/30
# ============================================================
# Training: 100%|██████████| 249/249 [39:27<00:00,  9.51s/it, loss=0.6289, acc=87.69%]
# Training: 100%|██████████| 249/249 [39:27<00:00,  9.51s/it, loss=0.6289, acc=87.69%]
# Evaluating: 100%|██████████| 62/62 [01:44<00:00,  1.69s/it, loss=1.6441, acc=91.83%]
# Learning Rate: 0.001000
#
# Epoch 7 Results:
#    Train Loss: 0.3380 | Train Acc: 87.69%
#    Val Loss:   0.2422 | Val Acc:   91.83%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_7.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold5/fold_1/best_accuracy.pt
#  New best model! Val Acc: 91.83%
#
# ============================================================
# Epoch 8/30
# ============================================================
# Training: 100%|██████████| 249/249 [42:53<00:00, 10.34s/it, loss=1.2421, acc=90.12%]
# Training: 100%|██████████| 249/249 [42:53<00:00, 10.34s/it, loss=1.2421, acc=90.12%]
# Evaluating: 100%|██████████| 62/62 [01:58<00:00,  1.92s/it, loss=1.4536, acc=91.38%]
# Learning Rate: 0.001000
#
# Epoch 8 Results:
#    Train Loss: 0.2729 | Train Acc: 90.12%
#    Val Loss:   0.2401 | Val Acc:   91.38%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_8.pth
#
# ============================================================
# Epoch 9/30
# ============================================================
# Training: 100%|██████████| 249/249 [43:38<00:00, 10.52s/it, loss=1.3190, acc=91.51%]
# Training: 100%|██████████| 249/249 [43:38<00:00, 10.52s/it, loss=1.3190, acc=91.51%]
# Evaluating: 100%|██████████| 62/62 [01:50<00:00,  1.78s/it, loss=1.7170, acc=94.61%]
# Learning Rate: 0.001000
#
# Epoch 9 Results:
#    Train Loss: 0.2332 | Train Acc: 91.51%
#    Val Loss:   0.1751 | Val Acc:   94.61%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_9.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold5/fold_1/best_accuracy.pt
#  New best model! Val Acc: 94.61%
#
# ============================================================
# Epoch 10/30
# ============================================================
# Training: 100%|██████████| 249/249 [47:17<00:00, 11.40s/it, loss=2.3081, acc=92.98%]
# Training: 100%|██████████| 249/249 [47:17<00:00, 11.40s/it, loss=2.3081, acc=92.98%]
# Evaluating: 100%|██████████| 62/62 [02:01<00:00,  1.97s/it, loss=1.7642, acc=95.31%]
# Learning Rate: 0.000100
#
# Epoch 10 Results:
#    Train Loss: 0.2053 | Train Acc: 92.98%
#    Val Loss:   0.1559 | Val Acc:   95.31%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_10.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold5/fold_1/best_accuracy.pt
#  New best model! Val Acc: 95.31%
#
# ============================================================
# Epoch 11/30
# ============================================================
# Training: 100%|██████████| 249/249 [45:53<00:00, 11.06s/it, loss=1.0332, acc=95.17%]
# Training: 100%|██████████| 249/249 [45:53<00:00, 11.06s/it, loss=1.0332, acc=95.17%]
# Evaluating: 100%|██████████| 62/62 [01:38<00:00,  1.59s/it, loss=1.6569, acc=95.46%]
# Learning Rate: 0.000100
#
# Epoch 11 Results:
#    Train Loss: 0.1510 | Train Acc: 95.17%
#    Val Loss:   0.1562 | Val Acc:   95.46%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_11.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold5/fold_1/best_accuracy.pt
#  New best model! Val Acc: 95.46%
# WARNING: EarlyStopping counter: 1/7
#
# ============================================================
# Epoch 12/30
# ============================================================
# Training: 100%|██████████| 249/249 [39:38<00:00,  9.55s/it, loss=2.2834, acc=95.87%]
# Training: 100%|██████████| 249/249 [39:38<00:00,  9.55s/it, loss=2.2834, acc=95.87%]
# Evaluating: 100%|██████████| 62/62 [01:30<00:00,  1.46s/it, loss=2.0277, acc=96.52%]
# Learning Rate: 0.000100
#
# Epoch 12 Results:
#    Train Loss: 0.1283 | Train Acc: 95.87%
#    Val Loss:   0.1289 | Val Acc:   96.52%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_12.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold5/fold_1/best_accuracy.pt
#  New best model! Val Acc: 96.52%
#
# ============================================================
# Epoch 13/30
# ============================================================
# Training: 100%|██████████| 249/249 [40:58<00:00,  9.88s/it, loss=1.0477, acc=95.85%]
# Training: 100%|██████████| 249/249 [40:58<00:00,  9.88s/it, loss=1.0477, acc=95.85%]
# Evaluating: 100%|██████████| 62/62 [01:43<00:00,  1.67s/it, loss=1.8243, acc=97.03%]
# Learning Rate: 0.000100
#
# Epoch 13 Results:
#    Train Loss: 0.1269 | Train Acc: 95.85%
#    Val Loss:   0.1202 | Val Acc:   97.03%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_13.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold5/fold_1/best_accuracy.pt
#  New best model! Val Acc: 97.03%
#
# ============================================================
# Epoch 14/30
# ============================================================
# Training: 100%|██████████| 249/249 [36:48<00:00,  8.87s/it, loss=0.8081, acc=96.30%]
# Training: 100%|██████████| 249/249 [36:48<00:00,  8.87s/it, loss=0.8081, acc=96.30%]
# Evaluating: 100%|██████████| 62/62 [01:23<00:00,  1.35s/it, loss=1.9652, acc=96.88%]
# Learning Rate: 0.000100
#
# Epoch 14 Results:
#    Train Loss: 0.1145 | Train Acc: 96.30%
#    Val Loss:   0.1194 | Val Acc:   96.88%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_14.pth
#
# ============================================================
# Epoch 15/30
# ============================================================
# Training: 100%|██████████| 249/249 [34:49<00:00,  8.39s/it, loss=0.4053, acc=96.37%]
# Training: 100%|██████████| 249/249 [34:49<00:00,  8.39s/it, loss=0.4053, acc=96.37%]
# Evaluating: 100%|██████████| 62/62 [01:23<00:00,  1.35s/it, loss=2.0158, acc=96.57%]
# Learning Rate: 0.000100
#
# Epoch 15 Results:
#    Train Loss: 0.1147 | Train Acc: 96.37%
#    Val Loss:   0.1175 | Val Acc:   96.57%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_15.pth
#
# ============================================================
# Epoch 16/30
# ============================================================
# Training: 100%|██████████| 249/249 [36:16<00:00,  8.74s/it, loss=2.1830, acc=96.35%]
# Training: 100%|██████████| 249/249 [36:16<00:00,  8.74s/it, loss=2.1830, acc=96.35%]
# Evaluating: 100%|██████████| 62/62 [01:30<00:00,  1.46s/it, loss=2.1899, acc=96.77%]
# Learning Rate: 0.000100
#
# Epoch 16 Results:
#    Train Loss: 0.1159 | Train Acc: 96.35%
#    Val Loss:   0.1128 | Val Acc:   96.77%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_16.pth
#
# ============================================================
# Epoch 17/30
# ============================================================
# Training: 100%|██████████| 249/249 [38:29<00:00,  9.28s/it, loss=2.1461, acc=96.30%]
# Training: 100%|██████████| 249/249 [38:29<00:00,  9.28s/it, loss=2.1461, acc=96.30%]
# Evaluating: 100%|██████████| 62/62 [01:36<00:00,  1.56s/it, loss=1.8425, acc=96.93%]
# Learning Rate: 0.000100
#
# Epoch 17 Results:
#    Train Loss: 0.1135 | Train Acc: 96.30%
#    Val Loss:   0.1106 | Val Acc:   96.93%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_17.pth
#
# ============================================================
# Epoch 18/30
# ============================================================
# Training: 100%|██████████| 249/249 [38:46<00:00,  9.34s/it, loss=2.3465, acc=96.27%]
# Training: 100%|██████████| 249/249 [38:46<00:00,  9.34s/it, loss=2.3465, acc=96.27%]
# Evaluating: 100%|██████████| 62/62 [01:34<00:00,  1.53s/it, loss=2.0951, acc=96.98%]
# Learning Rate: 0.000100
#
# Epoch 18 Results:
#    Train Loss: 0.1154 | Train Acc: 96.27%
#    Val Loss:   0.1186 | Val Acc:   96.98%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_18.pth
# WARNING: EarlyStopping counter: 1/7
#
# ============================================================
# Epoch 19/30
# ============================================================
# Training: 100%|██████████| 249/249 [38:19<00:00,  9.23s/it, loss=1.7513, acc=96.90%]
# Training: 100%|██████████| 249/249 [38:19<00:00,  9.23s/it, loss=1.7513, acc=96.90%]
# Evaluating: 100%|██████████| 62/62 [01:33<00:00,  1.51s/it, loss=1.8954, acc=97.13%]
# Learning Rate: 0.000100
#
# Epoch 19 Results:
#    Train Loss: 0.1028 | Train Acc: 96.90%
#    Val Loss:   0.1050 | Val Acc:   97.13%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_19.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold5/fold_1/best_accuracy.pt
#  New best model! Val Acc: 97.13%
#
# ============================================================
# Epoch 20/30
# ============================================================
# Training: 100%|██████████| 249/249 [39:06<00:00,  9.42s/it, loss=1.6375, acc=96.98%]
# Training: 100%|██████████| 249/249 [39:06<00:00,  9.42s/it, loss=1.6375, acc=96.98%]
# Evaluating: 100%|██████████| 62/62 [01:34<00:00,  1.53s/it, loss=2.0011, acc=96.62%]
# Learning Rate: 0.000010
#
# Epoch 20 Results:
#    Train Loss: 0.1013 | Train Acc: 96.98%
#    Val Loss:   0.1228 | Val Acc:   96.62%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_20.pth
# WARNING: EarlyStopping counter: 1/7
#
# ============================================================
# Epoch 21/30
# ============================================================
# Training: 100%|██████████| 249/249 [38:43<00:00,  9.33s/it, loss=1.0584, acc=96.99%]
# Training: 100%|██████████| 249/249 [38:43<00:00,  9.33s/it, loss=1.0584, acc=96.99%]
# Evaluating: 100%|██████████| 62/62 [01:34<00:00,  1.53s/it, loss=2.0985, acc=96.42%]
# Learning Rate: 0.000010
#
# Epoch 21 Results:
#    Train Loss: 0.1000 | Train Acc: 96.99%
#    Val Loss:   0.1291 | Val Acc:   96.42%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_21.pth
# WARNING: EarlyStopping counter: 2/7
#
# ============================================================
# Epoch 22/30
# ============================================================
# Training: 100%|██████████| 249/249 [39:06<00:00,  9.42s/it, loss=1.3965, acc=96.95%]
# Training: 100%|██████████| 249/249 [39:06<00:00,  9.42s/it, loss=1.3965, acc=96.95%]
# Evaluating: 100%|██████████| 62/62 [01:35<00:00,  1.54s/it, loss=1.8857, acc=96.77%]
# Learning Rate: 0.000010
#
# Epoch 22 Results:
#    Train Loss: 0.0978 | Train Acc: 96.95%
#    Val Loss:   0.1210 | Val Acc:   96.77%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_22.pth
# WARNING: EarlyStopping counter: 3/7
#
# ============================================================
# Epoch 23/30
# ============================================================
# Training: 100%|██████████| 249/249 [39:58<00:00,  9.63s/it, loss=0.5742, acc=97.00%]
# Training: 100%|██████████| 249/249 [39:58<00:00,  9.63s/it, loss=0.5742, acc=97.00%]
# Evaluating: 100%|██████████| 62/62 [01:35<00:00,  1.54s/it, loss=1.9161, acc=96.98%]
# Learning Rate: 0.000010
#
# Epoch 23 Results:
#    Train Loss: 0.0986 | Train Acc: 97.00%
#    Val Loss:   0.1171 | Val Acc:   96.98%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_23.pth
# WARNING: EarlyStopping counter: 4/7
#
# ============================================================
# Epoch 24/30
# ============================================================
# Training: 100%|██████████| 249/249 [39:37<00:00,  9.55s/it, loss=1.0273, acc=97.56%]
# Training: 100%|██████████| 249/249 [39:37<00:00,  9.55s/it, loss=1.0273, acc=97.56%]
# Evaluating: 100%|██████████| 62/62 [01:36<00:00,  1.55s/it, loss=1.8173, acc=97.23%]
# Learning Rate: 0.000010
#
# Epoch 24 Results:
#    Train Loss: 0.0852 | Train Acc: 97.56%
#    Val Loss:   0.1213 | Val Acc:   97.23%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_24.pth
# SUCCESS: Best model saved: checkpoints/mobilenet_fold5/fold_1/best_accuracy.pt
#  New best model! Val Acc: 97.23%
# WARNING: EarlyStopping counter: 5/7
#
# ============================================================
# Epoch 25/30
# ============================================================
# Training: 100%|██████████| 249/249 [39:45<00:00,  9.58s/it, loss=0.6218, acc=96.90%]
# Training: 100%|██████████| 249/249 [39:45<00:00,  9.58s/it, loss=0.6218, acc=96.90%]
# Evaluating: 100%|██████████| 62/62 [01:37<00:00,  1.58s/it, loss=1.9429, acc=97.13%]
# Learning Rate: 0.000010
#
# Epoch 25 Results:
#    Train Loss: 0.0982 | Train Acc: 96.90%
#    Val Loss:   0.1055 | Val Acc:   97.13%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_25.pth
# WARNING: EarlyStopping counter: 6/7
#
# ============================================================
# Epoch 26/30
# ============================================================
# Training: 100%|██████████| 249/249 [40:04<00:00,  9.65s/it, loss=2.1496, acc=97.18%]
# Training: 100%|██████████| 249/249 [40:04<00:00,  9.65s/it, loss=2.1496, acc=97.18%]
# Evaluating: 100%|██████████| 62/62 [01:38<00:00,  1.59s/it, loss=2.3458, acc=97.23%]
# Learning Rate: 0.000010
#
# Epoch 26 Results:
#    Train Loss: 0.0948 | Train Acc: 97.18%
#    Val Loss:   0.1127 | Val Acc:   97.23%
# SUCCESS: Checkpoint saved: checkpoints/mobilenet_fold5/fold_1/checkpoint_epoch_26.pth
# WARNING: EarlyStopping counter: 7/7
# SUCCESS: Early stopping triggered at epoch 26
# Best validation loss was 0.1050 at epoch 19
#
# ============================================================
# SUCCESS: Training stopped early at epoch 26/30
# Best Validation Accuracy: 97.23%
# ============================================================
#
# Fold 5 - Best Acc: 97.23% (stopped at epoch 26)
#
# ============================================================
# 5-FOLD CROSS-VALIDATION RESULTS
# ============================================================
# Mean Accuracy: 97.73% ± 0.36%
# Average Epochs: 27.8
#
# Individual Fold Results:
#   Fold 1: 98.09% (epoch 27)
#   Fold 2: 97.58% (epoch 30)
#   Fold 3: 98.19% (epoch 26)
#   Fold 4: 97.58% (epoch 30)
#   Fold 5: 97.23% (epoch 26)
# ============================================================

# %% [markdown]
# ## 5. Save Cross-Validation Results

# %%
# Configuration
MODEL_NAME = 'MobileNetV2'
BATCH_SIZE = 32
RESULTS_DIR = 'results'
CHECKPOINT_DIR = 'checkpoints'
N_FOLDS = 5
DPI = 300

# Plotting configuration
PLOT_CONFIG = {
    'cm': {'size': (10, 8), 'cmap': 'Blues'},
    'roc': {'size': (10, 8), 'lw': 2},
    'history': {'size': (18, 10)},
    'comparison': {'size': (10, 6)}
}
FONT = {'title': 14, 'label': 12, 'legend': 10, 'tick': 10}

# Save Cross-Validation Results and Generate Plots
import json
import os
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
import seaborn as sns

# Create model-specific results directory
model_results_dir = os.path.join(RESULTS_DIR, MODEL_NAME.lower())
os.makedirs(model_results_dir, exist_ok=True)
print(f"✓ Results directory created: {model_results_dir}")

# Verify directory exists
if os.path.exists(model_results_dir):
    print(f"✓ Directory verified: {os.path.abspath(model_results_dir)}")
else:
    print(f"⚠ Warning: Directory not found, creating again...")
    os.makedirs(model_results_dir, exist_ok=True)

# Get best fold
best_fold_idx = np.argmax([r['best_val_acc'] for r in fold_results])
best_fold_num = fold_results[best_fold_idx]['fold']

# Recreate validation set for best fold
fold_splits = list(kfold.split(X_all, y_all))
train_idx, val_idx = fold_splits[best_fold_idx]
val_dataset = DFUDataset(X_all[val_idx], y_all[val_idx], transform=val_test_transform)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

# Load best model
checkpoint_path = f'{CHECKPOINT_DIR}/mobilenet_fold{best_fold_num}/fold_1/best_accuracy.pt'

# Check if checkpoint exists
if not os.path.exists(checkpoint_path):
    print(f"Warning: Checkpoint not found at {checkpoint_path}")

else:
    model = create_mobilenet_model(num_classes=num_classes, pretrained=False)
    model.load_state_dict(torch.load(checkpoint_path))
    model = model.to(device).eval()
    print(f"✓ Loaded best model from {checkpoint_path}")

# Get predictions
all_preds, all_labels, all_probs = [], [], []
with torch.no_grad():
    for inputs, labels in val_loader:
        outputs = model(inputs.to(device))
        probs = torch.softmax(outputs, dim=1)
        all_probs.append(probs.cpu().numpy())
        all_preds.append(torch.max(outputs, 1)[1].cpu().numpy())
        all_labels.append(labels.numpy())

predictions = np.concatenate(all_preds)
true_labels = np.concatenate(all_labels)
y_pred_proba = np.vstack(all_probs)

# 1. Confusion Matrix (Raw Counts)
cm = confusion_matrix(true_labels, predictions)

fig, ax = plt.subplots(figsize=PLOT_CONFIG['cm']['size'])
sns.heatmap(cm, annot=True, fmt='d', cmap=PLOT_CONFIG['cm']['cmap'],
            xticklabels=classes, yticklabels=classes, ax=ax)
ax.set_xlabel('Predicted', fontsize=FONT['label'], fontweight='bold')
ax.set_ylabel('True', fontsize=FONT['label'], fontweight='bold')
ax.set_title(f'{MODEL_NAME} - Confusion Matrix (Fold {best_fold_num})', 
             fontsize=FONT['title'], fontweight='bold')
plt.tight_layout()
os.makedirs(model_results_dir, exist_ok=True)  # Ensure directory exists
plt.savefig(f'{model_results_dir}/{MODEL_NAME.lower()}_confusion_matrix.png', dpi=DPI, bbox_inches='tight')
plt.show()

# 2. Aggregated Confusion Matrix (All 5 Folds)
print("\n Generating aggregated confusion matrix across all folds...")
cm_aggregated = np.zeros((num_classes, num_classes), dtype=int)

for fold_idx, (train_idx, val_idx) in enumerate(fold_splits, 1):
    # Recreate validation set for this fold
    val_dataset_fold = DFUDataset(X_all[val_idx], y_all[val_idx], transform=val_test_transform)
    val_loader_fold = DataLoader(val_dataset_fold, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)
    
    # Load model for this fold
    fold_checkpoint_path = f'{CHECKPOINT_DIR}/mobilenet_fold{fold_idx}/fold_1/best_accuracy.pt'
    if os.path.exists(fold_checkpoint_path):
        model_fold = create_mobilenet_model(num_classes=num_classes, pretrained=False)
        model_fold.load_state_dict(torch.load(fold_checkpoint_path))
        model_fold = model_fold.to(device).eval()
        
        # Get predictions for this fold
        fold_preds, fold_labels = [], []
        with torch.no_grad():
            for inputs, labels in val_loader_fold:
                outputs = model_fold(inputs.to(device))
                fold_preds.append(torch.max(outputs, 1)[1].cpu().numpy())
                fold_labels.append(labels.numpy())
        
        # Accumulate confusion matrix
        fold_predictions = np.concatenate(fold_preds)
        fold_true_labels = np.concatenate(fold_labels)
        cm_fold = confusion_matrix(fold_true_labels, fold_predictions, labels=range(num_classes))
        cm_aggregated += cm_fold
        print(f"  ✓ Fold {fold_idx} processed")
    else:
        print(f"  ⚠ Fold {fold_idx} checkpoint not found, skipping")

# Normalize aggregated confusion matrix
cm_aggregated_norm = cm_aggregated.astype('float') / cm_aggregated.sum(axis=1)[:, np.newaxis]

# Plot aggregated confusion matrix
fig, ax = plt.subplots(figsize=PLOT_CONFIG['cm']['size'])
sns.heatmap(cm_aggregated_norm, annot=True, fmt='.2%', cmap=PLOT_CONFIG['cm']['cmap'],
            xticklabels=classes, yticklabels=classes, ax=ax)
ax.set_xlabel('Predicted', fontsize=FONT['label'], fontweight='bold')
ax.set_ylabel('True', fontsize=FONT['label'], fontweight='bold')
ax.set_title(f'{MODEL_NAME} - Aggregated Confusion Matrix (5-Fold CV)', 
             fontsize=FONT['title'], fontweight='bold')
plt.tight_layout()
os.makedirs(model_results_dir, exist_ok=True)  # Ensure directory exists
plt.savefig(f'{model_results_dir}/{MODEL_NAME.lower()}_confusion_matrix_aggregated.png', dpi=DPI, bbox_inches='tight')
plt.show()

print(f"✓ Aggregated confusion matrix saved ({cm_aggregated.sum()} total predictions)")

# 3. ROC Curve
y_true_bin = label_binarize(true_labels, classes=range(num_classes))
fig, ax = plt.subplots(figsize=PLOT_CONFIG['roc']['size'])

for i in range(num_classes):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_pred_proba[:, i])
    ax.plot(fpr, tpr, linewidth=PLOT_CONFIG['roc']['lw'], 
            label=f'{classes[i]} (AUC={auc(fpr, tpr):.2f})')

ax.plot([0, 1], [0, 1], 'k--', lw=1, label='Random')
ax.set_xlabel('FPR', fontsize=FONT['label'], fontweight='bold')
ax.set_ylabel('TPR', fontsize=FONT['label'], fontweight='bold')
ax.set_title(f'{MODEL_NAME} - ROC Curve (Fold {best_fold_num})', 
             fontsize=FONT['title'], fontweight='bold')
ax.legend(loc='lower right', fontsize=FONT['legend'])
ax.grid(alpha=0.3)
plt.tight_layout()
os.makedirs(model_results_dir, exist_ok=True)  # Ensure directory exists
plt.savefig(f'{model_results_dir}/{MODEL_NAME.lower()}_roc_curve.png', dpi=DPI, bbox_inches='tight')
plt.show()

# 4. All Folds Training History (Loss)
fig, axes = plt.subplots(2, 3, figsize=PLOT_CONFIG['history']['size'])
fig.suptitle(f'{MODEL_NAME} - {N_FOLDS}-Fold CV (Loss)', fontsize=FONT['title']+2, fontweight='bold')

for idx, r in enumerate(fold_results):
    ax = axes[idx // 3, idx % 3]
    history = r['history']
    epochs = range(1, len(history['train_loss']) + 1)
    
    ax.plot(epochs, history['train_loss'], 'b-', label='Train', lw=2)
    ax.plot(epochs, history['val_loss'], 'r-', label='Val', lw=2)
    ax.axvline(x=history['val_loss'].index(min(history['val_loss'])) + 1, 
               color='g', linestyle='--', alpha=0.5, label='Best Val')
    if r['stopped_epoch'] < len(epochs):
        ax.axvline(x=r['stopped_epoch'], color='orange', linestyle='--', alpha=0.5, label='Stopped')
    
    ax.set_xlabel('Epoch', fontsize=FONT['tick'])
    ax.set_ylabel('Loss', fontsize=FONT['tick'])
    ax.set_title(f"Fold {r['fold']}: {r['best_val_acc']*100:.2f}%", fontweight='bold')
    ax.legend(fontsize=FONT['tick']-2)
    ax.grid(alpha=0.3)

axes[1, 2].axis('off')
plt.tight_layout()
os.makedirs(model_results_dir, exist_ok=True)  # Ensure directory exists
plt.savefig(f'{model_results_dir}/{MODEL_NAME.lower()}_all_folds_loss.png', dpi=DPI, bbox_inches='tight')
plt.show()

# 5. All Folds Training History (Accuracy)
fig, axes = plt.subplots(2, 3, figsize=PLOT_CONFIG['history']['size'])
fig.suptitle(f'{MODEL_NAME} - {N_FOLDS}-Fold CV (Accuracy)', fontsize=FONT['title']+2, fontweight='bold')

for idx, r in enumerate(fold_results):
    ax = axes[idx // 3, idx % 3]
    history = r['history']
    epochs = range(1, len(history['train_acc']) + 1)
    
    # Convert to percentage
    train_acc_pct = [acc * 100 for acc in history['train_acc']]
    val_acc_pct = [acc * 100 for acc in history['val_acc']]
    
    ax.plot(epochs, train_acc_pct, 'b-', label='Train', lw=2)
    ax.plot(epochs, val_acc_pct, 'r-', label='Val', lw=2)
    ax.axvline(x=history['val_acc'].index(max(history['val_acc'])) + 1, 
               color='g', linestyle='--', alpha=0.5, label='Best Val')
    if r['stopped_epoch'] < len(epochs):
        ax.axvline(x=r['stopped_epoch'], color='orange', linestyle='--', alpha=0.5, label='Stopped')
    
    ax.set_xlabel('Epoch', fontsize=FONT['tick'])
    ax.set_ylabel('Accuracy (%)', fontsize=FONT['tick'])
    ax.set_title(f"Fold {r['fold']}: {r['best_val_acc']*100:.2f}%", fontweight='bold')
    ax.legend(fontsize=FONT['tick']-2)
    ax.grid(alpha=0.3)
    ax.set_ylim([0, 100])

axes[1, 2].axis('off')
plt.tight_layout()
os.makedirs(model_results_dir, exist_ok=True)  # Ensure directory exists
plt.savefig(f'{model_results_dir}/{MODEL_NAME.lower()}_all_folds_accuracy.png', dpi=DPI, bbox_inches='tight')
plt.show()

# Save results
results = {
    'model_name': MODEL_NAME,
    'cv_results': {
        'val_accuracy': {'mean': float(avg_acc), 'std': float(std_acc)},
        'avg_epochs': float(avg_epochs),
        'fold_results': [{'fold': r['fold'], 'best_val_acc': float(r['best_val_acc']), 
                          'stopped_epoch': int(r['stopped_epoch'])} for r in fold_results]
    },
    'best_fold': {
        'fold_number': best_fold_num, 
        'best_val_acc': float(fold_results[best_fold_idx]['best_val_acc']),
        'checkpoint_path': checkpoint_path
    }
}

os.makedirs(model_results_dir, exist_ok=True)  # Ensure directory exists
with open(f'{model_results_dir}/{MODEL_NAME.lower()}_results.json', 'w') as f:
    json.dump(results, f, indent=2)

print(f"\n{'='*60}")
print(f"{MODEL_NAME} CROSS-VALIDATION SUMMARY")
print(f"{'='*60}")
print(f"Mean Accuracy: {avg_acc*100:.2f}% ± {std_acc*100:.2f}%")
print(f"Best Fold: {best_fold_num} ({fold_results[best_fold_idx]['best_val_acc']*100:.2f}%)")
print(f"Average Epochs: {avg_epochs:.1f}")
print(f"{'='*60}")
# Out:
# ✓ Results directory created: results/mobilenetv2
# ✓ Directory verified: /Users/manaralharbi/Desktop/KHOTAA/models/classification/results/mobilenetv2
# ✓ Loaded best model from checkpoints/mobilenet_fold3/fold_1/best_accuracy.pt
#  Generating aggregated confusion matrix across all folds...
#   ✓ Fold 1 processed
#   ✓ Fold 2 processed
#   ✓ Fold 3 processed
#   ✓ Fold 4 processed
#   ✓ Fold 5 processed
# ✓ Aggregated confusion matrix saved (9921 total predictions)
# ============================================================
# MobileNetV2 CROSS-VALIDATION SUMMARY
# ============================================================
# Mean Accuracy: 97.73% ± 0.36%
# Best Fold: 3 (98.19%)
# Average Epochs: 27.8
# ============================================================

# %% [markdown]
# ## 6. Generate Comprehensive Metrics JSON

# %%
import sys
import os
import json
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import models
from torchvision.models import MobileNet_V2_Weights
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import confusion_matrix, roc_auc_score
from sklearn.preprocessing import label_binarize
from datetime import datetime
from PIL import Image

# Add paths
sys.path.append('../')
sys.path.append('./')

# Import dataset modules
from dataset_loader import SplitFolderDatasetLoader
from dataset_preprocessing import DFUPreprocessing

print("="*80)
print("GENERATING COMPREHENSIVE METRICS FROM SAVED CHECKPOINTS")
print("="*80)

# ============================================================================
# CONFIGURATION
# ============================================================================
MODEL_NAME = 'MobileNetV2'
BATCH_SIZE = 32
RESULTS_DIR = 'results'
CHECKPOINT_DIR = 'checkpoints'
N_FOLDS = 5

# ============================================================================
# LOAD DATASET
# ============================================================================
print("\n[1/5] Loading dataset...")
loader = SplitFolderDatasetLoader(root_dir='../../dfu-dataset-annotated-into-4-classes')
classes = loader.get_classes()
num_classes = loader.get_num_classes()

preprocessor = DFUPreprocessing()
val_test_transform = preprocessor.get_valid_test_transforms()

# Dataset class
class DFUDataset(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.transform = transform
    
    def __len__(self):
        return len(self.image_paths)
    
    def __getitem__(self, idx):
        image = Image.open(self.image_paths[idx]).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, self.labels[idx]

# Prepare data
X_train, y_train = loader.load_split_paths('train', shuffle=True)
X_val, y_val = loader.load_split_paths('valid')
X_all = np.concatenate([X_train, X_val])
y_all = np.concatenate([y_train, y_val])
X_test, y_test = loader.load_split_paths('test')

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

print(f"✓ Loaded {len(X_all)} training samples, {len(X_test)} test samples")
print(f"✓ Classes: {classes}")

# ============================================================================
# MODEL DEFINITION
# ============================================================================
def create_mobilenet_model(num_classes=4, pretrained=False):
    if pretrained:
        model = models.mobilenet_v2(weights=MobileNet_V2_Weights.IMAGENET1K_V1)
    else:
        model = models.mobilenet_v2(weights=None)
    model.classifier[1] = nn.Linear(model.classifier[1].in_features, num_classes)
    return model

# ============================================================================
# LOAD SAVED RESULTS
# ============================================================================
print("\n[2/5] Loading saved results...")
model_results_dir = os.path.join(RESULTS_DIR, MODEL_NAME.lower())
results_json_path = f'{model_results_dir}/{MODEL_NAME.lower()}_results.json'

if not os.path.exists(results_json_path):
    print(f" ERROR: Results file not found at {results_json_path}")
    print("\nPlease run cell 5 first to save the cross-validation results.")
    raise FileNotFoundError(f"Results file not found: {results_json_path}")

with open(results_json_path, 'r') as f:
    saved_results = json.load(f)

# Reconstruct fold_results
fold_results = []
for fold_data in saved_results['cv_results']['fold_results']:
    fold_results.append({
        'fold': fold_data['fold'],
        'best_val_acc': fold_data['best_val_acc'],
        'final_val_acc': fold_data.get('final_val_acc', fold_data['best_val_acc']),
        'stopped_epoch': fold_data['stopped_epoch']
    })

avg_acc = saved_results['cv_results']['val_accuracy']['mean']
std_acc = saved_results['cv_results']['val_accuracy']['std']
avg_epochs = saved_results['cv_results']['avg_epochs']

print(f"✓ Loaded CV results: {avg_acc*100:.2f}% ± {std_acc*100:.2f}%")

# ============================================================================
# FIND AND LOAD BEST MODEL
# ============================================================================
print("\n[3/5] Loading best model from checkpoint...")
best_fold_idx = np.argmax([r['best_val_acc'] for r in fold_results])
best_fold_num = fold_results[best_fold_idx]['fold']
checkpoint_path = f'{CHECKPOINT_DIR}/mobilenet_fold{best_fold_num}/fold_1/best_accuracy.pt'

if not os.path.exists(checkpoint_path):
    print(f" ERROR: Checkpoint not found at {checkpoint_path}")
    print("\nAvailable checkpoints:")
    for fold in range(1, 6):
        cp_path = f'{CHECKPOINT_DIR}/mobilenet_fold{fold}/fold_1/best_accuracy.pt'
        if os.path.exists(cp_path):
            print(f"  ✓ Fold {fold}: {cp_path}")
        else:
            print(f"  ✗ Fold {fold}: Not found")
    raise FileNotFoundError(f"Checkpoint not found: {checkpoint_path}")

model = create_mobilenet_model(num_classes=num_classes, pretrained=False)
model.load_state_dict(torch.load(checkpoint_path, map_location=device))
model = model.to(device).eval()

print(f"✓ Loaded best model from fold {best_fold_num}")

# ============================================================================
# EVALUATE BEST MODEL
# ============================================================================
print("\n[4/5] Evaluating best model on validation set...")
fold_splits = list(kfold.split(X_all, y_all))
train_idx, val_idx = fold_splits[best_fold_idx]
val_dataset = DFUDataset(X_all[val_idx], y_all[val_idx], transform=val_test_transform)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

# Get predictions
all_preds, all_labels, all_probs = [], [], []
with torch.no_grad():
    for inputs, labels in val_loader:
        outputs = model(inputs.to(device))
        probs = torch.softmax(outputs, dim=1)
        all_probs.append(probs.cpu().numpy())
        all_preds.append(torch.max(outputs, 1)[1].cpu().numpy())
        all_labels.append(labels.numpy())

predictions = np.concatenate(all_preds)
true_labels = np.concatenate(all_labels)
y_pred_proba = np.vstack(all_probs)

print(f"✓ Evaluated {len(true_labels)} samples")

# ============================================================================
# CALCULATE METRICS
# ============================================================================
print("\n[5/5] Calculating comprehensive metrics...")

# Per-class metrics
per_class_metrics = {}
for i, class_name in enumerate(classes):
    class_mask = (true_labels == i)
    class_preds = (predictions == i)
    
    tp = np.sum((class_preds == True) & (class_mask == True))
    fp = np.sum((class_preds == True) & (class_mask == False))
    fn = np.sum((class_preds == False) & (class_mask == True))
    tn = np.sum((class_preds == False) & (class_mask == False))
    
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0.0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0.0
    
    y_true_bin = label_binarize(true_labels, classes=range(num_classes))
    try:
        auc_score = roc_auc_score(y_true_bin[:, i], y_pred_proba[:, i])
    except:
        auc_score = 0.0
    
    per_class_metrics[class_name] = {
        'precision': float(precision),
        'recall': float(recall),
        'f1_score': float(f1),
        'specificity': float(specificity),
        'sensitivity': float(recall),
        'auc': float(auc_score),
        'support': int(np.sum(class_mask)),
        'true_positives': int(tp),
        'false_positives': int(fp),
        'false_negatives': int(fn),
        'true_negatives': int(tn)
    }

# Confusion matrix
cm = confusion_matrix(true_labels, predictions)

# ============================================================================
# COMPILE AND SAVE COMPREHENSIVE RESULTS
# ============================================================================
comprehensive_results = {
    'model_info': {
        'model_name': MODEL_NAME,
        'architecture': 'MobileNetV2',
        'pretrained': True,
        'pretrained_weights': 'ImageNet (IMAGENET1K_V1)',
        'input_size': [3, 224, 224],
        'num_classes': num_classes,
        'class_names': classes
    },
    'training_config': {
        'optimizer': 'SGD',
        'learning_rate_initial': 0.001,
        'learning_rate_schedule': 'StepLR',
        'lr_step_size': 10,
        'lr_gamma': 0.1,
        'momentum': 0.9,
        'batch_size': BATCH_SIZE,
        'num_epochs': 30,
        'early_stopping_patience': 7,
        'loss_function': 'CrossEntropyLoss'
    },
    'dataset_info': {
        'dataset_name': 'DFU Dataset (4 Classes)',
        'total_samples': len(X_all) + len(X_test),
        'training_samples': len(X_all),
        'test_samples': len(X_test),
        'num_folds': N_FOLDS,
        'stratified': True,
        'class_distribution': {
            class_name: int(np.sum(y_all == i)) 
            for i, class_name in enumerate(classes)
        }
    },
    'cross_validation': {
        'num_folds': N_FOLDS,
        'mean_accuracy': float(avg_acc),
        'std_accuracy': float(std_acc),
        'min_accuracy': float(min([r['best_val_acc'] for r in fold_results])),
        'max_accuracy': float(max([r['best_val_acc'] for r in fold_results])),
        'average_epochs': float(avg_epochs),
        'best_fold': {
            'fold_number': int(best_fold_num),
            'accuracy': float(fold_results[best_fold_idx]['best_val_acc']),
            'stopped_epoch': int(fold_results[best_fold_idx]['stopped_epoch'])
        },
        'individual_folds': [
            {
                'fold': r['fold'],
                'best_val_accuracy': float(r['best_val_acc']),
                'final_val_accuracy': float(r['final_val_acc']),
                'stopped_epoch': int(r['stopped_epoch'])
            }
            for r in fold_results
        ]
    },
    'validation_results': {
        'best_fold_number': int(best_fold_num),
        'per_class_metrics': per_class_metrics,
        'confusion_matrix': {
            'matrix': cm.tolist(),
            'normalized': (cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]).tolist(),
            'labels': classes
        },
        'total_samples': len(true_labels),
        'correct_predictions': int(np.sum(predictions == true_labels)),
        'incorrect_predictions': int(np.sum(predictions != true_labels)),
        'accuracy': float(np.sum(predictions == true_labels) / len(true_labels))
    },
    'metadata': {
        'timestamp': datetime.now().isoformat(),
        'framework': 'PyTorch',
        'pytorch_version': torch.__version__,
        'cuda_available': torch.cuda.is_available(),
        'experiment_name': 'mobilenet_5fold_cv',
        'checkpoint_path': checkpoint_path,
        'generated_standalone': True
    }
}

# Save to JSON
os.makedirs(model_results_dir, exist_ok=True)
comprehensive_json_path = f'{model_results_dir}/{MODEL_NAME.lower()}_comprehensive_metrics.json'

with open(comprehensive_json_path, 'w') as f:
    json.dump(comprehensive_results, f, indent=2)

# ============================================================================
# DISPLAY SUMMARY
# ============================================================================
print("\n" + "="*80)
print("COMPREHENSIVE METRICS SUMMARY")
print("="*80)

print(f"\nMODEL: {MODEL_NAME}")

print(f"\nCROSS-VALIDATION (5-Fold):")
print(f"  Mean Accuracy: {avg_acc*100:.2f}% ± {std_acc*100:.2f}%")
print(f"  Best Fold: {best_fold_num} ({fold_results[best_fold_idx]['best_val_acc']*100:.2f}%)")
print(f"  Average Epochs: {avg_epochs:.1f}")

print(f"\nVALIDATION SET (Best Fold {best_fold_num}):")
print(f"  Total Samples: {len(true_labels)}")
print(f"  Correct: {np.sum(predictions == true_labels)}")
print(f"  Incorrect: {np.sum(predictions != true_labels)}")
print(f"  Accuracy: {comprehensive_results['validation_results']['accuracy']*100:.2f}%")

print(f"\nPER-CLASS METRICS:")
for class_name, metrics_dict in per_class_metrics.items():
    print(f"\n  {class_name} (n={metrics_dict['support']}):")
    print(f"    Precision:   {metrics_dict['precision']:.4f}")
    print(f"    Recall:      {metrics_dict['recall']:.4f}")
    print(f"    F1-Score:    {metrics_dict['f1_score']:.4f}")
    print(f"    Specificity: {metrics_dict['specificity']:.4f}")
    print(f"    AUC:         {metrics_dict['auc']:.4f}")

print(f"\n{'='*80}")
print(f"✓ Saved comprehensive metrics to:")
print(f"  {os.path.abspath(comprehensive_json_path)}")
file_size = os.path.getsize(comprehensive_json_path) / 1024
print(f"  File size: {file_size:.2f} KB")
print("="*80)
print("COMPLETE ✓")
print("="*80)
# Out:
# ================================================================================
# GENERATING COMPREHENSIVE METRICS FROM SAVED CHECKPOINTS
# ================================================================================
#
# [1/5] Loading dataset...
# [DatasetLoader] Root: /Users/manaralharbi/Desktop/KHOTAA/dfu-dataset-annotated-into-4-classes
# [DatasetLoader] Splits: ['train', 'valid', 'test']
# [DatasetLoader] Classes (4): ['Grade 1', 'Grade 2', 'Grade 3', 'Grade 4']
# [DFUPreprocessing] Initialized
# [DFUPreprocessing] Image size: 224x224
# [DFUPreprocessing] Train: with augmentation
# [DFUPreprocessing] Valid/Test: no augmentation
# [DatasetLoader] Split 'train': 9639 images
# [DatasetLoader] Split 'valid': 282 images
# [DatasetLoader] Split 'test': 141 images
# ✓ Loaded 9921 training samples, 141 test samples
# ✓ Classes: ['Grade 1', 'Grade 2', 'Grade 3', 'Grade 4']
#
# [2/5] Loading saved results...
# ✓ Loaded CV results: 97.73% ± 0.36%
#
# [3/5] Loading best model from checkpoint...
# ✓ Loaded best model from fold 3
#
# [4/5] Evaluating best model on validation set...
# ✓ Evaluated 1984 samples
#
# [5/5] Calculating comprehensive metrics...
#
# ================================================================================
# COMPREHENSIVE METRICS SUMMARY
# ================================================================================
#
# MODEL: MobileNetV2
#
# CROSS-VALIDATION (5-Fold):
#   Mean Accuracy: 97.73% ± 0.36%
#   Best Fold: 3 (98.19%)
#   Average Epochs: 27.8
#
# VALIDATION SET (Best Fold 3):
#   Total Samples: 1984
#   Correct: 1966
#   Incorrect: 18
#   Accuracy: 99.09%
#
# PER-CLASS METRICS:
#
#   Grade 1 (n=465):
#     Precision:   0.9892
#     Recall:      0.9892
#     F1-Score:    0.9892
#     Specificity: 0.9967
#     AUC:         0.9997
#
#   Grade 2 (n=485):
#     Precision:   0.9856
#     Recall:      0.9897
#     F1-Score:    0.9877
#     Specificity: 0.9953
#     AUC:         0.9996
#
#   Grade 3 (n=557):
#     Precision:   0.9910
#     Recall:      0.9892
#     F1-Score:    0.9901
#     Specificity: 0.9965
#     AUC:         0.9998
#
#   Grade 4 (n=477):
#     Precision:   0.9979
#     Recall:      0.9958
#     F1-Score:    0.9969
#     Specificity: 0.9993
#     AUC:         1.0000
#
# ================================================================================
# ✓ Saved comprehensive metrics to:
#   /Users/manaralharbi/Desktop/KHOTAA/models/classification/results/mobilenetv2/mobilenetv2_comprehensive_metrics.json
#   File size: 5.26 KB
# ================================================================================
# COMPLETE ✓
# ================================================================================
# ✓ Evaluated 1984 samples
#
# [5/5] Calculating comprehensive metrics...
#
# ================================================================================
# COMPREHENSIVE METRICS SUMMARY
# ================================================================================
#
# MODEL: MobileNetV2
#
# CROSS-VALIDATION (5-Fold):
#   Mean Accuracy: 97.73% ± 0.36%
#   Best Fold: 3 (98.19%)
#   Average Epochs: 27.8
#
# VALIDATION SET (Best Fold 3):
#   Total Samples: 1984
#   Correct: 1966
#   Incorrect: 18
#   Accuracy: 99.09%
#
# PER-CLASS METRICS:
#
#   Grade 1 (n=465):
#     Precision:   0.9892
#     Recall:      0.9892
#     F1-Score:    0.9892
#     Specificity: 0.9967
#     AUC:         0.9997
#
#   Grade 2 (n=485):
#     Precision:   0.9856
#     Recall:      0.9897
#     F1-Score:    0.9877
#     Specificity: 0.9953
#     AUC:         0.9996
#
#   Grade 3 (n=557):
#     Precision:   0.9910
#     Recall:      0.9892
#     F1-Score:    0.9901
#     Specificity: 0.9965
#     AUC:         0.9998
#
#   Grade 4 (n=477):
#     Precision:   0.9979
#     Recall:      0.9958
#     F1-Score:    0.9969
#     Specificity: 0.9993
#     AUC:         1.0000
#
# ================================================================================
# ✓ Saved comprehensive metrics to:
#   /Users/manaralharbi/Desktop/KHOTAA/models/classification/results/mobilenetv2/mobilenetv2_comprehensive_metrics.json
#   File size: 5.26 KB
# ================================================================================
# COMPLETE ✓
# ================================================================================
